# %%
import arcpy
import os
import numpy as np
import pandas as pd
import csv
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats as st
from sklearn.neighbors import KernelDensity
from sklearn.model_selection import GridSearchCV, KFold, RepeatedKFold
#import statsmodels as sm
import math
import warnings
from datetime import datetime, timedelta

# %% [markdown]
# In order to calculate "aggregate" Gini, we need to be able to spatially apply census blocks / block groups / tracts to the income features that they overlap with / contain.
# 1. To speed this up, limit the census blocks we care about to just Minnesota

# %%
def Income_Groups_From_Shape_File(input_shape, input_shape_statefips_name):
    """
    ## Filter shape file down to just Minnesota for speed
    print("Creating subset of shape file just for Minnesota data...")
    t1 = datetime.now()
    # Select only census blocks in MN
    arcpy.SelectLayerByAttribute_management(input_shape, 
                                            'NEW_SELECTION', 
                                            input_shape_statefips_name+" = '27'")

    # Write the selected features to a new featureclass
    arcpy.CopyFeatures_management(input_shape, input_shape+"_mn")
    t2 = datetime.now()
    t2_delta = t2-t1
    print("Created Subset of {0} for only Minnesota in {1} seconds ({2} minutes)".format(
        input_shape,
        t2_delta.total_seconds(),
        t2_delta.total_seconds()/60))
        """
    
    print("Assigning income points to groups...")
    ## Create income means by block, block group, tract, county
    t1 = datetime.now()
    arcpy.SpatialJoin_analysis('rti_income_feature_class', # target_features
                               input_shape+'_mn', # join_features 
                               'rti_income_by_group', # out_feature_class
                               'JOIN_ONE_TO_ONE', # join_operation
                               'KEEP_ALL', # join_type
                               None, # field_mapping
                               'WITHIN', # match_option
                               None, # search_radius
                               None # distance_field_name
                               )
    t2 = datetime.now()
    t2_delta = t2-t1
    print("Assigned income points to {0} in {1} seconds ({2} minutes)".format(
        shape_group_name,
        t2_delta.total_seconds(), 
        t2_delta.total_seconds()/60))
    
    print("Saving feature layer...")
    ## export grouped feature class to table for Gini calculation
    out_location = 'C:\\Users\\alex\\Documents\\code\\maup_income_inequality\\maup_inequality\\outputs\\'
    out_filename = "rti_income_by_group.csv"
    outtable = arcpy.TableToTable_conversion(
                        in_rows = 'rti_income_by_group', 
                        out_path = out_location, 
                        out_name = out_filename)
    return

# %% [markdown]
# Having saved the file with each income and its containing block / block group / etc., we read in the file and then group by the level we want to calculate. Mean income is calculated at that level and any

# %%
default_plot_store_location = "C:\\Users\\alex\\Documents\\code\\maup_income_inequality\\maup_inequality\\outputs\\"

def Plot_Lorenz_Curve(incomelist, ax, gini_group, line_style="b-"):
    #incomelist = incomelist.flatten()
    
    # generate x axis array
    len_list = incomelist.shape[0]
    indices = np.arange(len_list, dtype=np.longdouble)   # create list of indices
    x_axis = np.divide(indices, len_list)   # normalize indices to 0-1
    x_axis = x_axis
    
    # generate y axis array
    incomelist = incomelist.astype(np.longdouble)   # values, esp. sum, can get very large
    incomelist = np.sort(incomelist)   # we want this curve to lie below the optimal
    incsum = np.sum(incomelist, dtype=np.longdouble)
    incomelist = np.divide(incomelist, incsum)   # normalize values 0-1
    cdf = np.cumsum(incomelist)   # Calculate cdf so that last element is 1
    
    # plot empirical curve
    if (gini_group == 'Household Incomes'):
        ax.plot(x_axis, cdf, line_style, label=gini_group)
    else:
        ax.plot(x_axis, cdf, line_style, label="Average Household Income")
    return


def Plot_One_Lorenz_Curve(incomelist, store_location=default_plot_store_location, gini_group="Household Incomes"):
    fig, ax = plt.subplots(figsize=(8, 4))

    Plot_Lorenz_Curve(incomelist, ax, gini_group)
    
    # plot theoretically perfect equality
    ax.plot(ax.get_xlim(), ax.get_ylim(), "k--", label='Theoretical Equal Incomes')
    
    # Save figure
    ax.grid(True)
    ax.legend(loc='upper left')
    #title = 'Lorenz Curve for ' + gini_group
    title = gini_group
    ax.set_title(title)
    ax.set_xlabel('Cumulative Portion of Groups')
    ax.set_ylabel('Cumulative Portion of Income')
    fname = store_location + title + ".png"
    fig.savefig(fname)
    return


def Plot_All_Lorenz_Curves(incomelist_list, gini_group_list, store_location=default_plot_store_location, location="Minnesota"):
    line_styles = ['b-', 'g-', 'r-', 'c-', 'm-', 'y-']
    num_curves = len(incomelist_list)
    
    fig, ax = plt.subplots(figsize=(9,5))
    
    for i in range(num_curves):
        incomelist = incomelist_list[i].astype(dtype=np.longdouble)
        Plot_One_Lorenz_Curve(incomelist=incomelist, 
                              gini_group=gini_group_list[i])
        
        Plot_Lorenz_Curve(incomelist=incomelist, 
                          ax=ax, 
                          gini_group=gini_group_list[i], 
                          line_style=line_styles[i])
    
    # plot theoretically perfect equality
    ax.plot(ax.get_xlim(), ax.get_ylim(), "k--", label='Theoretical Equal Incomes')
    
    # Save figure
    ax.grid(True)
    ax.legend(loc='upper left')
    title = 'Lorenz Curves for Spatial Partitions in {0}'.format(location)
    ax.set_title(title)
    ax.set_xlabel('Cumulative Portion of Groups')
    ax.set_ylabel('Cumulative Portion of Income')
    fname = store_location + title + ".png"
    fig.savefig(fname)
    return
    
    
# Computationally efficient Gini function (from https://github.com/oliviaguest/gini) 
#    and https://www.statsdirect.com/help/default.htm#nonparametric_methods/gini.htm
def gini(array):
    array = array.flatten().astype(np.longdouble)
    #print("Calculating Gini. Example of data: ")
    #print(array[:5])
    # Values cannot be negative:
    if (np.amin(array) < 0):
        array -= np.amin(array)
    
    # Sort values:
    array = np.sort(array)
    
    # Index and count of array elements:
    index = np.arange(1,array.shape[0]+1)
    n = array.shape[0]
    
    # Gini coefficient:
    return (   (  np.sum(( (2*index) - n - 1 ) * array)  ) / (n * np.sum(array))   )


def Theil_L(array):
    array = array.flatten().astype(np.longdouble)
    array_length = array.shape[0]
    
    # Values cannot be negative or 0 - replace them with small number
    array[array <= 0] = 1
    
    array_mean = array.mean()
    ratio_array = np.divide(array_mean, array)
    log_array = np.log(ratio_array)
    return (np.sum(log_array) / array_length)

def Theil_T(array):
    array = array.flatten().astype(np.longdouble)
    array_length = array.shape[0]
    
    # Values cannot be negative or 0 - replace them with small number
    array[array <= 0] = 1
    
    array_mean = array.mean()
    ratio_array = np.divide(array, array_mean)
    log_array = np.log(ratio_array)
    return (np.sum(np.multiply(ratio_array, log_array)) / array_length)

def Atkinson(array, eps):
    array = array.flatten().astype(np.longdouble)
    array_length = array.shape[0]
    
    # Values cannot be negative - replace them with small number
    array[array <= 0] = 0
    
    array_mean = array.mean()
    #print("Array mean: {0}".format(array_mean))
    powered_array = np.power(array, (1.0-eps))
    #print("Powered_array[0]: {0}".format(powered_array[0]))
    #divided_array = numpy.divide(powered_array, array_length)
    powered_sum = np.sum(powered_array, dtype=np.longdouble)
    #print("powered sum: {0}".format(powered_sum))
    atkinson = (powered_sum / array_length)
    #print("atkinson 1: {0}".format(atkinson))
    atkinson = np.power(atkinson, (1.0/(1.0-eps)))
    #print("atkinson 2: {0}".format(atkinson))
    atkinson = (1.0 / array_mean) * atkinson
    #print("atkinson 3: {0}".format(atkinson))
    return (1.0-atkinson)


def Gini_From_Shape_File(path_to_csv, location="Minnesota"):
    print("Reading grouped incomes in as raster")
    incomelist = pd.read_csv(filepath_or_buffer=path_to_csv,
                                 header=0,
                                 index_col=False,
                                 usecols=['hh_income', 'GEOID', 'COUNTY', 'TRACT', 'BLKGRP', 'BLOCK'],
                                 engine='c')

    # drop rows with NA - if there's no data for a census block, we will ignore it
    #incomelist = incomelist.dropna()
    na_sums = incomelist.isnull().sum()
    print("Are there any incomes which were not contained within a census tract? Yes if any of these columns are not 0: ")
    print(na_sums)
    
    ginigroup_list = []
    # calculate gini on all data
    incomes = incomelist['hh_income'].to_numpy(dtype=np.longdouble)
    groupname = "Household Incomes"
    ginigroup_list.append(groupname)
    g = gini(incomes)
    l = Theil_L(incomes)
    t = Theil_T(incomes)
    a_25 = Atkinson(incomes, 0.25)
    a_50 = Atkinson(incomes, 0.5)
    a_75 = Atkinson(incomes, 0.75)
    print("~~Ungrouped incomes:\nGini is {0}\nTheil's L is {1}\nTheil's T is {2}\nAtkinson with eps=0.25 is {3}\nAtkinson with eps=0.5 is {4}\nAtkinson with eps=0.75 is {5}".format(g, l, t, a_25, a_50, a_75))
    
    # calculate mean income of each census block
    mean_income = incomelist.groupby(['COUNTY', 'TRACT', 'BLKGRP', 'BLOCK']).mean()
    mean_income.hh_income = mean_income.hh_income.astype(np.longdouble)
    mean_block_incomes = mean_income['hh_income'].to_numpy(dtype=np.longdouble)
    #print(mean_income.head)
    #groupname = "Average Household Income per Census Block"
    groupname = "Census Block"
    ginigroup_list.append(groupname)
    g = gini(mean_block_incomes)
    l = Theil_L(mean_block_incomes)
    t = Theil_T(mean_block_incomes)
    a_25 = Atkinson(mean_block_incomes, 0.25)
    a_50 = Atkinson(mean_block_incomes, 0.5)
    a_75 = Atkinson(mean_block_incomes, 0.75)
    print("~~Block Averages:\nGini is {0}\nTheil's L is {1}\nTheil's T is {2}\nAtkinson with eps=0.25 is {3}\nAtkinson with eps=0.5 is {4}\nAtkinson with eps=0.75 is {5}".format(g, l, t, a_25, a_50, a_75))

    # calculate mean income of each census block group
    mean_income = incomelist.groupby(['COUNTY', 'TRACT', 'BLKGRP']).mean()
    mean_income.hh_income = mean_income.hh_income.astype(np.longdouble)
    mean_block_group_incomes = mean_income['hh_income'].to_numpy(dtype=np.longdouble)
    #groupname="Average Household Income per Census Block Group"
    groupname="Census Block Group"
    ginigroup_list.append(groupname)
    g = gini(mean_block_group_incomes)
    l = Theil_L(mean_block_group_incomes)
    t = Theil_T(mean_block_group_incomes)
    a_25 = Atkinson(mean_block_group_incomes, 0.25)
    a_50 = Atkinson(mean_block_group_incomes, 0.5)
    a_75 = Atkinson(mean_block_group_incomes, 0.75)
    print("~~Block Group Averages:\nGini is {0}\nTheil's L is {1}\nTheil's T is {2}\nAtkinson with eps=0.25 is {3}\nAtkinson with eps=0.5 is {4}\nAtkinson with eps=0.75 is {5}".format(g, l, t, a_25, a_50, a_75))

    # calculate mean income of each census tract
    mean_income = incomelist.groupby(['COUNTY', 'TRACT']).mean()
    mean_income.hh_income = mean_income.hh_income.astype(np.longdouble)
    mean_tract_incomes = mean_income['hh_income'].to_numpy(dtype=np.longdouble)
    #groupname="Average Household Income per Census Tract"
    groupname="Census Tract"
    ginigroup_list.append(groupname)
    g = gini(mean_tract_incomes)
    l = Theil_L(mean_tract_incomes)
    t = Theil_T(mean_tract_incomes)
    a_25 = Atkinson(mean_tract_incomes, 0.25)
    a_50 = Atkinson(mean_tract_incomes, 0.5)
    a_75 = Atkinson(mean_tract_incomes, 0.75)
    print("~~Tract Averages:\nGini is {0}\nTheil's L is {1}\nTheil's T is {2}\nAtkinson with eps=0.25 is {3}\nAtkinson with eps=0.5 is {4}\nAtkinson with eps=0.75 is {5}".format(g, l, t, a_25, a_50, a_75))

    # calculate mean income of each county
    mean_income = incomelist.groupby(['COUNTY']).mean()
    mean_income.hh_income = mean_income.hh_income.astype(np.longdouble)
    mean_county_incomes = mean_income['hh_income'].to_numpy(dtype=np.longdouble)
    #groupname="Average Household Income per County"
    groupname="County"
    ginigroup_list.append(groupname)
    g = gini(mean_county_incomes)
    l = Theil_L(mean_county_incomes)
    t = Theil_T(mean_county_incomes)
    a_25 = Atkinson(mean_county_incomes, 0.25)
    a_50 = Atkinson(mean_county_incomes, 0.5)
    a_75 = Atkinson(mean_county_incomes, 0.75)
    print("~~County Averages:\nGini is {0}\nTheil's L is {1}\nTheil's T is {2}\nAtkinson with eps=0.25 is {3}\nAtkinson with eps=0.5 is {4}\nAtkinson with eps=0.75 is {5}".format(g, l, t, a_25, a_50, a_75))
    
    print("Plotting all lorenz curves...")
    incomelist_list = numpy.array([incomes, 
                                   mean_block_incomes, 
                                   mean_block_group_incomes, 
                                   mean_tract_incomes, 
                                   mean_county_incomes], dtype=object)
    Plot_All_Lorenz_Curves(incomelist_list, gini_group_list=ginigroup_list, location=location)

# %%
Income_Groups_From_Shape_File('census_blocks', 'STATE')
# Out:
# Creating subset of shape file just for Minnesota data...
# Created Subset of Census Blocks for only Minnesota in 2611.333974 seconds (43.5222329 minutes)
# Assigning income points to groups...
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# In  [47]:
# Line 1:     Income_Groups_From_Shape_File('Census Blocks', 'STATE')
#
# In  [44]:
# Line 30:    None # distance_field_name
#
# File c:\program files\arcgis\pro\Resources\arcpy\arcpy\analysis.py, in SpatialJoin:
# Line 672:   raise e
#
# File c:\program files\arcgis\pro\Resources\arcpy\arcpy\analysis.py, in SpatialJoin:
# Line 669:   retval = convertArcObjectToPythonObject(gp.SpatialJoin_analysis(*gp_fixargs((target_features, join_features, out_feature_class, join_operation, join_type, field_mapping, match_option, search_radius, distance_field_name), True)))
#
# File c:\program files\arcgis\pro\Resources\arcpy\arcpy\geoprocessing\_base.py, in <lambda>:
# Line 511:   return lambda *args: val(*gp_fixargs(args, True))
#
# ExecuteError: Failed to execute. Parameters are not valid.
# ERROR 000732: Join Features: Dataset Census Blocks_mn does not exist or is not supported
# Failed to execute (SpatialJoin).
#
# ---------------------------------------------------------------------------

# %%
Income_Groups_From_Shape_File('census_blocks', 'STATE')
# Out:
# Assigning income points to groups...
# Assigned income points to census_block_group in 251.161122 seconds (4.1860187 minutes)
# Saving feature layer...

# %%
in_location = 'C:\\Users\\alex\\Documents\\code\\maup_income_inequality\\maup_inequality\\outputs\\'
input_filename = 'rti_income_by_group.csv'
path_to_csv = in_location + input_filename

Gini_From_Shape_File(path_to_csv, location="Minnesota")
# Out:
# Reading grouped incomes in as raster
# Are there any incomes which were not contained within a census tract? Yes if any of these columns are not 0:
# hh_income    0
# GEOID        0
# COUNTY       0
# TRACT        0
# BLKGRP       0
# BLOCK        0
# dtype: int64
# ~~Ungrouped incomes:
# Gini is 0.3146037264674286
# Theil's L is 0.4352327721678018
# Theil's T is 0.3414651819388614
# Atkinson with eps=0.25 is 0.08358900648588519
# Atkinson with eps=0.5 is 0.16521380452084355
# Atkinson with eps=0.75 is 0.2504586890450309
# ~~Block Averages:
# Gini is 0.23808408386972563
# Theil's L is 0.15201736620969805
# Theil's T is 0.13894946071824077
# Atkinson with eps=0.25 is 0.03434092849884074
# Atkinson with eps=0.5 is 0.06833289671036724
# Atkinson with eps=0.75 is 0.10306264357580708
# ~~Block Group Averages:
# Gini is 0.20780887864538042
# Theil's L is 0.07125117855715496
# Theil's T is 0.06928845544025283
# Atkinson with eps=0.25 is 0.017277150409923614
# Atkinson with eps=0.5 is 0.03447691644784501
# Atkinson with eps=0.75 is 0.051627476401250094
# ~~Tract Averages:
# Gini is 0.18468354100213139
# Theil's L is 0.054956664098001935
# Theil's T is 0.054476935105956664
# Atkinson with eps=0.25 is 0.013555154542845504
# Atkinson with eps=0.5 is 0.026982193919609654
# Atkinson with eps=0.75 is 0.04028523001335471
# ~~County Averages:
# Gini is 0.08208026615730417
# Theil's L is 0.012507676562135726
# Theil's T is 0.013520669433917474
# Atkinson with eps=0.25 is 0.003309091160539235
# Atkinson with eps=0.5 is 0.006479848676894884
# Atkinson with eps=0.75 is 0.009518106511836266
# Plotting all lorenz curves...

# %% [markdown]
# # Inequality in Hennepin County
# Run the above calculation, limiting income features to Hennepin County.

# %%
out_location = 'C:\\Users\\alex\\Documents\\code\\maup_income_inequality\\maup_inequality\\outputs\\'

# Save table to csv for pandas processing
print("Saving feature layer...")
## export grouped feature class to table for Gini calculation
out_filename = "hennepin_incomes.csv"
outtable = arcpy.TableToTable_conversion(
                    in_rows = 'hennepin_incomes', 
                    out_path = out_location, 
                    out_name = out_filename)

# Calculate inequality measures from file
#path_to_csv = arcpy.env.workspace + out_filename
path_to_csv = os.path.join(out_location, out_filename)
Gini_From_Shape_File(path_to_csv, location="Hennepin County")
# Out:
# Saving feature layer...
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# In  [193]:
# Line 10:    out_name = out_filename)
#
# File c:\program files\arcgis\pro\Resources\arcpy\arcpy\conversion.py, in TableToTable:
# Line 2158:  raise e
#
# File c:\program files\arcgis\pro\Resources\arcpy\arcpy\conversion.py, in TableToTable:
# Line 2155:  retval = convertArcObjectToPythonObject(gp.TableToTable_conversion(*gp_fixargs((in_rows, out_path, out_name, where_clause, field_mapping, config_keyword), True)))
#
# File c:\program files\arcgis\pro\Resources\arcpy\arcpy\geoprocessing\_base.py, in <lambda>:
# Line 511:   return lambda *args: val(*gp_fixargs(args, True))
#
# ExecuteError: ERROR 999999: Something unexpected caused the tool to fail. Contact Esri Technical Support (http://esriurl.com/support) to Report a Bug, and refer to the error help for potential solutions or workarounds.
# Failed to execute (TableToTable).
#
# ---------------------------------------------------------------------------

# %% [markdown]
# # Monotonic Decrease in Hierarchical Measurements
#
# We see that Theil's L, Theil's T, and Atkinson all tend to decrease as we aggregate up a hierarchy. We can explain it this way: assume we start with zones at level 1, and level 2 contains not any more zones, where some zones from level 1 are combined to form the zones of level 2, and the income values within level 1 zones are averaged when merging takes place. The mean of a set of values cannot be greater than the largest value in the set, or smaller than the smallest value in the set. At the extremes, it can be equal to these when there is only one value being averaged or when all values are equal.
#
# # Analysis of non-Hierarchical Zonal Statistics
#
# We would like to study the same statistics calculated on zones that are not hierarchical, but that are subject to the same constraint such as approximately equal number of inhabitants. By generating a set of zones subject to a level 1 constraint (set Z1 subj. to L1), and calculating the statistics on them, then repeating the process with a new set (Z2, Z3, ..., Zn  | L1), we will generate a distribution of our statistics subject to L1. We can perform the following evaluations:
#     1. How do the census zones compare to the distribution (assuming that L1 ~ constraint in the census zone scheme)?
#     2. How does the distribution of a statistic generally change across "monotonic" constraints L1 < L2 < ... < Lm?
#     3. Can we approximate the empirical distribution with a known theoretical density, such as Gaussian?

# %%
# Restrict RTI incomes to just hennepin county incomes
arcpy.MakeFeatureLayer_management(in_features='rti_income_by_group', 
                                  out_layer='hennepin_incomes', 
                                  where_clause="COUNTY = '053'")
arcpy.CalculateField_management(in_table='hennepin_incomes',
                                field='Point_count_int',
                                expression='1',
                                field_type='SHORT')
# Out:
# <Result 'hennepin_incomes'>

# %%
# Restrict census blocks to just hennepin county blocks
arcpy.MakeFeatureLayer_management(in_features='census_blocks_mn',
                                 out_layer='hennepin_blocks_mn',
                                 where_clause="COUNTY = '053'")
arcpy.CalculateField_management(in_table='census_blocks_mn',
                               field='Point_count_int',
                               expression='1',
                               field_type='SHORT')
# Out:
# <Result 'census_blocks_mn'>

# %%
def Stats_From_Sim_File(path_to_csv, iteration, supress_output=False):
    print("Reading grouped incomes in as raster (simulation {0})".format(iteration))
    incomelist = pd.read_csv(filepath_or_buffer=path_to_csv,
                                 header=0,
                                 index_col=False,
                                 usecols=['hh_income', 'ZONE_ID', 'BLOCK', 'POP100', 'BLKGRP', 'TRACT', 'COUNTY'],
                                 engine='c')

    # drop rows with NA - if there's no data for a census block, we will ignore it
    #incomelist = incomelist.dropna()
    na_sums = incomelist.isnull().sum()
    if (not supress_output):
        print("Are there any incomes which were not contained within a census tract? Yes if any of these columns are not 0: ")
        print(na_sums)
    
    ginigroup_list = []
    
    # Calculate stats on this simulated zone schema
    # How many zones?
    num_zones = incomelist['ZONE_ID'].nunique()
    # Average number of blocks per zone, min/max number of blocks per zone
    number_unique_blocks_series = incomelist.groupby(['ZONE_ID'])['BLOCK'].nunique()
    avg_num_blocks_per_zone = number_unique_blocks_series.mean()
    min_num_blocks_per_zone = number_unique_blocks_series.min()
    max_num_blocks_per_zone = number_unique_blocks_series.max()
    # Average population per zone, min/max population per zone
    unique_blocks = incomelist.drop_duplicates(subset=["BLOCK", "BLKGRP", "TRACT", "COUNTY"])
    population_per_zone = unique_blocks.groupby(['ZONE_ID']).sum()['POP100']
    mean_zone_pop = population_per_zone.mean()
    min_zone_pop = population_per_zone.min()
    max_zone_pop = population_per_zone.max()
    # Average number of households per zone, min/max number of households per zone
    households_per_zone = incomelist.groupby(['ZONE_ID']).count()['hh_income']
    mean_zone_hhcount = households_per_zone.mean()
    min_zone_hhcount = households_per_zone.min()
    max_zone_hhcount = households_per_zone.max()
    
    
    # calculate mean income of each zone
    mean_income = incomelist.groupby(['ZONE_ID']).mean()
    mean_income.hh_income = mean_income.hh_income.astype(np.longdouble)
    mean_zone_incomes = mean_income['hh_income'].to_numpy(dtype=np.longdouble)
    groupname="Average Household Income per Zone (Sim {0})".format(iteration)
    ginigroup_list.append(groupname)
    g = gini(mean_zone_incomes)
    l = Theil_L(mean_zone_incomes)
    t = Theil_T(mean_zone_incomes)
    a_25 = Atkinson(mean_zone_incomes, 0.25)
    a_50 = Atkinson(mean_zone_incomes, 0.5)
    a_75 = Atkinson(mean_zone_incomes, 0.75)
    if (not supress_output):
        print("~~Simulation {0} Zone Statistics:\nGini is {1}\nTheil's L is {2}\nTheil's T is {3}\nAtkinson with eps=0.25 is {4}\nAtkinson with eps=0.5 is {5}\nAtkinson with eps=0.75 is {6}".format(iteration, g, l, t, a_25, a_50, a_75))
        Plot_One_Lorenz_Curve(mean_zone_incomes, store_location=default_plot_store_location, gini_group="Average Zone Incomes (Sim {0})".format(iteration))
    
    res = {
        'iteration': iteration,
        'gini': g, 
        'theil_l': l, 
        'theil_t': t,
        'atkinson_25': a_25, 
        'atkinson_50': a_50, 
        'atkinson_75': a_75,
        'num_zones': num_zones,
        'avg_num_blocks_per_zone': avg_num_blocks_per_zone,
        'min_num_blocks_per_zone': min_num_blocks_per_zone,
        'max_num_blocks_per_zone': max_num_blocks_per_zone,
        'mean_zone_pop': mean_zone_pop,
        'min_zone_pop': min_zone_pop,
        'max_zone_pop': max_zone_pop,
        'mean_zone_hhcount': mean_zone_hhcount,
        'min_zone_hhcount': min_zone_hhcount,
        'max_zone_hhcount': max_zone_hhcount        
    }
    return res

# %%
def Run_Simulation(num_iterations=1, pop_target=4000, zone_characteristic_goal='COMPACTNESS', continue_from_failure=False, resume_iter=0):
    if (continue_from_failure):
        print("Continuing simulation with {0} iterations, starting from iteration {1}. Zones will be built with population goals of {2} and zone characteristic {3}".format(
                num_iterations,
                resume_iter,
                pop_target,
                zone_characteristic_goal)
             )
    else:
        print("Starting simulation with {0} iterations. Zones will be built with population goals of {1} and zone characteristic {2}".format(
                num_iterations,
                pop_target,
                zone_characteristic_goal)
             )
    out_location = 'C:\\Users\\alex\\Documents\\code\\maup_income_inequality\\maup_inequality\\outputs\\simulation_' + str(num_iterations) + "_" + str(pop_target) + "_" + zone_characteristic_goal + "\\" 
    if not os.path.exists(out_location):
        os.mkdir(out_location)
        
    # create file to hold results
    sim_results = out_location + "results.csv"
    if (not continue_from_failure):
        fieldnames = ['iteration', 'gini', 'theil_l', 'theil_t', 'atkinson_25', 'atkinson_50', 'atkinson_75', 'num_zones', 
                        'avg_num_blocks_per_zone', 'min_num_blocks_per_zone','max_num_blocks_per_zone','mean_zone_pop','min_zone_pop', 
                        'max_zone_pop','mean_zone_hhcount', 'min_zone_hhcount','max_zone_hhcount']
        with open(sim_results, 'w', newline='') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()

    start_time = datetime.now() # for measuring time
    for i in range(resume_iter, num_iterations):
        print("Starting iteration #{0}".format(i))
        iter_start_time = datetime.now()
        fitness_scores = "convergence_results_" + str(i)
        arcpy.CreateTable_management(out_path = arcpy.env.workspace, 
                                     out_name = fitness_scores) # hold the convergence results
        
        print("Building zones with a target population of {0} individuals".format(pop_target))
        zone_build_start_time = datetime.now()
        arcpy.stats.BuildBalancedZones(in_features = 'hennepin_blocks_mn',
                                       output_features = 'temp_bbz',
                                       zone_creation_method = 'ATTRIBUTE_TARGET',
                                       number_of_zones = None,
                                       zone_building_criteria_target = [['POP100', pop_target, 1]],
                                       zone_building_criteria = None,
                                       spatial_constraints = 'CONTIGUITY_EDGES_ONLY',
                                       weights_matrix_file = None,
                                       zone_characteristics = zone_characteristic_goal, 
                                       attribute_to_consider = None,
                                       distance_to_consider = None,
                                       categorial_variable = None,
                                       proportion_method = None,
                                       population_size = 200,
                                       number_generations = 20,
                                       mutation_factor = 0.1,
                                       output_convergence_table = fitness_scores
                                       )
        zone_build_end_time = datetime.now()
        zone_build_duration = zone_build_end_time - zone_build_start_time
        print("Built zones in {0} seconds.".format(zone_build_duration.total_seconds()))

        # Fill zones with income features
        print("Applying zones to point features...")
        join_start_time = datetime.now()
        arcpy.SpatialJoin_analysis('hennepin_incomes', # target_features
                               'temp_bbz', # join_features 
                               'temp_zone_inc', # out_feature_class
                               'JOIN_ONE_TO_ONE', # join_operation
                               'KEEP_ALL', # join_type
                               None, # field_mapping
                               'WITHIN', # match_option
                               None, # search_radius
                               None # distance_field_name
                               )
        join_end_time = datetime.now()
        join_duration = join_end_time - join_start_time
        print("Assigned income points to zones in {0} seconds ({1} minutes)".format(
            join_duration.total_seconds(), 
            join_duration.total_seconds()/60))

        # Save table to csv for pandas processing
        print("Saving feature layer...")
        ## export grouped feature class to table for Gini calculation
        #out_filename = "zone_sims_" + str(i) + ".csv"
        out_filename = "zone_sims_temp.csv"
        outtable = arcpy.TableToTable_conversion(
                            in_rows = 'temp_zone_inc', 
                            out_path = out_location, 
                            out_name = out_filename)

        # Calculate inequality measures from file
        #path_to_csv = arcpy.env.workspace + out_filename
        path_to_csv = os.path.join(out_location, out_filename)
        res = Stats_From_Sim_File(path_to_csv, i, supress_output=True)
        
        # Done with iteration, write results to file
        with open(sim_results, 'a', newline='') as csvfile:
            fieldnames = list(res.keys())
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writerow(res)
        
        # Print iteration runtime stats
        iter_end_time = datetime.now()
        iter_duration = iter_end_time - iter_start_time
        print("Ran iteration {0} in {1} seconds ({2} minutes)".format(i, 
                                                                      iter_duration.total_seconds(),
                                                                      iter_duration.total_seconds()/60)
             )

    # Done with simulation, print runtime stats
    end_time = datetime.now()
    print('Done with all simulations! Time elapsed:',end_time - start_time)

# %%
Run_Simulation(num_iterations=100, pop_target=4000, zone_characteristic_goal='COMPACTNESS')
# Out:
# Starting simulation with 100 iterations. Zones will be built with population goals of 4000 and zone characteristic COMPACTNESS
# Starting iteration #0
# Building zones with a target population of 4000 individuals
# Built zones in 65.377687 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.028062 seconds (0.9671343666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 0)
# Ran iteration 0 in 195.668416 seconds (3.2611402666666667 minutes)
# Starting iteration #1
# Building zones with a target population of 4000 individuals
# Built zones in 64.016244 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.568472 seconds (0.9261412 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 1)
# Ran iteration 1 in 191.382793 seconds (3.1897132166666666 minutes)
# Starting iteration #2
# Building zones with a target population of 4000 individuals
# Built zones in 62.078853 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.322664 seconds (0.9220444000000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 2)
# Ran iteration 2 in 189.21112 seconds (3.1535186666666664 minutes)
# Starting iteration #3
# Building zones with a target population of 4000 individuals
# Built zones in 61.843338 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.903525 seconds (0.9317254166666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 3)
# Ran iteration 3 in 190.282893 seconds (3.17138155 minutes)
# Starting iteration #4
# Building zones with a target population of 4000 individuals
# Built zones in 66.206852 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.969397 seconds (0.9328232833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 4)
# Ran iteration 4 in 194.361222 seconds (3.2393537 minutes)
# Starting iteration #5
# Building zones with a target population of 4000 individuals
# Built zones in 65.18305 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.514494 seconds (1.0085749 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 5)
# Ran iteration 5 in 199.376678 seconds (3.3229446333333335 minutes)
# Starting iteration #6
# Building zones with a target population of 4000 individuals
# Built zones in 67.412868 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.43561 seconds (0.9572601666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 6)
# Ran iteration 6 in 197.526745 seconds (3.292112416666667 minutes)
# Starting iteration #7
# Building zones with a target population of 4000 individuals
# Built zones in 69.778064 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.228099 seconds (0.9371349833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 7)
# Ran iteration 7 in 198.58909 seconds (3.3098181666666666 minutes)
# Starting iteration #8
# Building zones with a target population of 4000 individuals
# Built zones in 66.565012 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.414726 seconds (0.9402454333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 8)
# Ran iteration 8 in 195.321441 seconds (3.2553573499999997 minutes)
# Starting iteration #9
# Building zones with a target population of 4000 individuals
# Built zones in 67.799675 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.859921 seconds (0.94766535 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 9)
# Ran iteration 9 in 197.346238 seconds (3.2891039666666666 minutes)
# Starting iteration #10
# Building zones with a target population of 4000 individuals
# Built zones in 68.898656 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.138865 seconds (0.93564775 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 10)
# Ran iteration 10 in 197.892315 seconds (3.29820525 minutes)
# Starting iteration #11
# Building zones with a target population of 4000 individuals
# Built zones in 72.491173 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.221913 seconds (0.9203652166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 11)
# Ran iteration 11 in 198.98517 seconds (3.3164195000000003 minutes)
# Starting iteration #12
# Building zones with a target population of 4000 individuals
# Built zones in 63.571539 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.184422 seconds (0.9697403666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 12)
# Ran iteration 12 in 196.025581 seconds (3.2670930166666663 minutes)
# Starting iteration #13
# Building zones with a target population of 4000 individuals
# Built zones in 70.413488 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.280757 seconds (0.92134595 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 13)
# Ran iteration 13 in 197.053392 seconds (3.2842232 minutes)
# Starting iteration #14
# Building zones with a target population of 4000 individuals
# Built zones in 68.244072 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.372233 seconds (0.9228705500000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 14)
# Ran iteration 14 in 196.115572 seconds (3.2685928666666664 minutes)
# Starting iteration #15
# Building zones with a target population of 4000 individuals
# Built zones in 68.994925 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.18996 seconds (0.9198326666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 15)
# Ran iteration 15 in 196.133362 seconds (3.268889366666667 minutes)
# Starting iteration #16
# Building zones with a target population of 4000 individuals
# Built zones in 72.541851 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.217748 seconds (0.9202958 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 16)
# Ran iteration 16 in 201.00325 seconds (3.3500541666666668 minutes)
# Starting iteration #17
# Building zones with a target population of 4000 individuals
# Built zones in 70.742822 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.394437 seconds (0.9232406166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 17)
# Ran iteration 17 in 197.120711 seconds (3.2853451833333334 minutes)
# Starting iteration #18
# Building zones with a target population of 4000 individuals
# Built zones in 67.728836 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.857515 seconds (0.9309585833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 18)
# Ran iteration 18 in 194.92437 seconds (3.2487395 minutes)
# Starting iteration #19
# Building zones with a target population of 4000 individuals
# Built zones in 73.074012 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.370421 seconds (0.92284035 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 19)
# Ran iteration 19 in 199.595009 seconds (3.326583483333333 minutes)
# Starting iteration #20
# Building zones with a target population of 4000 individuals
# Built zones in 66.843588 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.444811 seconds (0.9240801833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 20)
# Ran iteration 20 in 193.411924 seconds (3.2235320666666665 minutes)
# Starting iteration #21
# Building zones with a target population of 4000 individuals
# Built zones in 70.31882 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.403326 seconds (0.9233887666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 21)
# Ran iteration 21 in 197.273068 seconds (3.2878844666666667 minutes)
# Starting iteration #22
# Building zones with a target population of 4000 individuals
# Built zones in 66.768851 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.574043 seconds (0.92623405 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 22)
# Ran iteration 22 in 193.081061 seconds (3.2180176833333336 minutes)
# Starting iteration #23
# Building zones with a target population of 4000 individuals
# Built zones in 71.284749 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.305349 seconds (0.9217558166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 23)
# Ran iteration 23 in 198.146773 seconds (3.3024462166666666 minutes)
# Starting iteration #24
# Building zones with a target population of 4000 individuals
# Built zones in 72.337153 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.406326 seconds (0.9234387666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 24)
# Ran iteration 24 in 198.996943 seconds (3.3166157166666665 minutes)
# Starting iteration #25
# Building zones with a target population of 4000 individuals
# Built zones in 67.939798 seconds.
# Applying zones to point features...
# Assigned income points to zones in 76.840152 seconds (1.2806692 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 25)
# Ran iteration 25 in 217.661363 seconds (3.6276893833333332 minutes)
# Starting iteration #26
# Building zones with a target population of 4000 individuals
# Built zones in 68.630698 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.44156 seconds (0.9406926666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 26)
# Ran iteration 26 in 198.004214 seconds (3.3000702333333334 minutes)
# Starting iteration #27
# Building zones with a target population of 4000 individuals
# Built zones in 78.771826 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.472506 seconds (0.9412084333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 27)
# Ran iteration 27 in 209.185945 seconds (3.4864324166666667 minutes)
# Starting iteration #28
# Building zones with a target population of 4000 individuals
# Built zones in 68.493238 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.93692 seconds (0.9989486666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 28)
# Ran iteration 28 in 206.295316 seconds (3.438255266666667 minutes)
# Starting iteration #29
# Building zones with a target population of 4000 individuals
# Built zones in 80.069617 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.096933 seconds (0.9849488833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 29)
# Ran iteration 29 in 212.621098 seconds (3.5436849666666665 minutes)
# Starting iteration #30
# Building zones with a target population of 4000 individuals
# Built zones in 75.930844 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.591099 seconds (0.9931849833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 30)
# Ran iteration 30 in 211.571135 seconds (3.526185583333333 minutes)
# Starting iteration #31
# Building zones with a target population of 4000 individuals
# Built zones in 78.631139 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.884217 seconds (0.9814036166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 31)
# Ran iteration 31 in 214.043271 seconds (3.5673878500000002 minutes)
# Starting iteration #32
# Building zones with a target population of 4000 individuals
# Built zones in 75.566561 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.863022 seconds (1.0643837 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 32)
# Ran iteration 32 in 216.371373 seconds (3.6061895500000003 minutes)
# Starting iteration #33
# Building zones with a target population of 4000 individuals
# Built zones in 90.125445 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.03397 seconds (0.9505661666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 33)
# Ran iteration 33 in 222.036495 seconds (3.70060825 minutes)
# Starting iteration #34
# Building zones with a target population of 4000 individuals
# Built zones in 78.380806 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.70867 seconds (0.9451444999999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 34)
# Ran iteration 34 in 209.722219 seconds (3.4953703166666665 minutes)
# Starting iteration #35
# Building zones with a target population of 4000 individuals
# Built zones in 85.819104 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.471531 seconds (0.9578588499999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 35)
# Ran iteration 35 in 217.332058 seconds (3.6222009666666666 minutes)
# Starting iteration #36
# Building zones with a target population of 4000 individuals
# Built zones in 89.39134 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.943497 seconds (0.96572495 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 36)
# Ran iteration 36 in 220.808158 seconds (3.6801359666666666 minutes)
# Starting iteration #37
# Building zones with a target population of 4000 individuals
# Built zones in 87.572389 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.63331 seconds (0.9438885 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 37)
# Ran iteration 37 in 217.954397 seconds (3.6325732833333335 minutes)
# Starting iteration #38
# Building zones with a target population of 4000 individuals
# Built zones in 95.792127 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.081301 seconds (0.9513550166666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 38)
# Ran iteration 38 in 228.053181 seconds (3.80088635 minutes)
# Starting iteration #39
# Building zones with a target population of 4000 individuals
# Built zones in 91.07284 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.723363 seconds (0.9453893833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 39)
# Ran iteration 39 in 220.503917 seconds (3.6750652833333333 minutes)
# Starting iteration #40
# Building zones with a target population of 4000 individuals
# Built zones in 74.833701 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.880116 seconds (0.9480019333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 40)
# Ran iteration 40 in 204.921732 seconds (3.4153621999999997 minutes)
# Starting iteration #41
# Building zones with a target population of 4000 individuals
# Built zones in 89.329913 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.335002 seconds (0.9389167 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 41)
# Ran iteration 41 in 218.766449 seconds (3.646107483333333 minutes)
# Starting iteration #42
# Building zones with a target population of 4000 individuals
# Built zones in 73.574268 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.822443 seconds (0.9970407166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 42)
# Ran iteration 42 in 210.356287 seconds (3.505938116666667 minutes)
# Starting iteration #43
# Building zones with a target population of 4000 individuals
# Built zones in 92.953049 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.495059 seconds (0.9582509833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 43)
# Ran iteration 43 in 224.275798 seconds (3.737929966666667 minutes)
# Starting iteration #44
# Building zones with a target population of 4000 individuals
# Built zones in 96.792875 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.910907 seconds (0.9985151166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 44)
# Ran iteration 44 in 234.559856 seconds (3.9093309333333335 minutes)
# Starting iteration #45
# Building zones with a target population of 4000 individuals
# Built zones in 85.150542 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.387734 seconds (0.9564622333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 45)
# Ran iteration 45 in 217.186639 seconds (3.6197773166666667 minutes)
# Starting iteration #46
# Building zones with a target population of 4000 individuals
# Built zones in 86.505866 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.613066 seconds (0.9602177666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 46)
# Ran iteration 46 in 218.365472 seconds (3.6394245333333335 minutes)
# Starting iteration #47
# Building zones with a target population of 4000 individuals
# Built zones in 88.925947 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.147399 seconds (0.9857899833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 47)
# Ran iteration 47 in 220.869661 seconds (3.6811610166666666 minutes)
# Starting iteration #48
# Building zones with a target population of 4000 individuals
# Built zones in 75.165081 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.082727 seconds (0.96804545 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 48)
# Ran iteration 48 in 204.902189 seconds (3.415036483333333 minutes)
# Starting iteration #49
# Building zones with a target population of 4000 individuals
# Built zones in 73.246521 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.49962 seconds (0.9249936666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 49)
# Ran iteration 49 in 200.446372 seconds (3.3407728666666667 minutes)
# Starting iteration #50
# Building zones with a target population of 4000 individuals
# Built zones in 75.058622 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.262508 seconds (0.9210417999999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 50)
# Ran iteration 50 in 200.565288 seconds (3.3427548000000002 minutes)
# Starting iteration #51
# Building zones with a target population of 4000 individuals
# Built zones in 73.745593 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.710267 seconds (0.92850445 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 51)
# Ran iteration 51 in 200.690147 seconds (3.344835783333333 minutes)
# Starting iteration #52
# Building zones with a target population of 4000 individuals
# Built zones in 73.207262 seconds.
# Applying zones to point features...
# Assigned income points to zones in 54.207486 seconds (0.9034581 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 52)
# Ran iteration 52 in 200.298226 seconds (3.338303766666667 minutes)
# Starting iteration #53
# Building zones with a target population of 4000 individuals
# Built zones in 75.327047 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.57913 seconds (1.0429855 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 53)
# Ran iteration 53 in 209.538701 seconds (3.4923116833333334 minutes)
# Starting iteration #54
# Building zones with a target population of 4000 individuals
# Built zones in 75.801287 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.015701 seconds (0.96692835 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 54)
# Ran iteration 54 in 203.654872 seconds (3.394247866666667 minutes)
# Starting iteration #55
# Building zones with a target population of 4000 individuals
# Built zones in 78.32341 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.094098 seconds (0.9349016333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 55)
# Ran iteration 55 in 207.865953 seconds (3.4644325499999997 minutes)
# Starting iteration #56
# Building zones with a target population of 4000 individuals
# Built zones in 74.938444 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.942378 seconds (0.9323729666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 56)
# Ran iteration 56 in 203.365086 seconds (3.3894181 minutes)
# Starting iteration #57
# Building zones with a target population of 4000 individuals
# Built zones in 74.284439 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.026704 seconds (0.9337784 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 57)
# Ran iteration 57 in 202.514071 seconds (3.3752345166666666 minutes)
# Starting iteration #58
# Building zones with a target population of 4000 individuals
# Built zones in 74.26266 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.045604 seconds (0.9340934 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 58)
# Ran iteration 58 in 202.022507 seconds (3.3670417833333333 minutes)
# Starting iteration #59
# Building zones with a target population of 4000 individuals
# Built zones in 74.848128 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.657183 seconds (0.9276197166666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 59)
# Ran iteration 59 in 202.609223 seconds (3.376820383333333 minutes)
# Starting iteration #60
# Building zones with a target population of 4000 individuals
# Built zones in 75.109105 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.994085 seconds (0.93323475 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 60)
# Ran iteration 60 in 203.098725 seconds (3.38497875 minutes)
# Starting iteration #61
# Building zones with a target population of 4000 individuals
# Built zones in 75.32086 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.386566 seconds (0.9397761 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 61)
# Ran iteration 61 in 203.248123 seconds (3.3874687166666666 minutes)
# Starting iteration #62
# Building zones with a target population of 4000 individuals
# Built zones in 75.515631 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.201778 seconds (0.9366962999999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 62)
# Ran iteration 62 in 203.686962 seconds (3.3947827 minutes)
# Starting iteration #63
# Building zones with a target population of 4000 individuals
# Built zones in 75.439974 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.072002 seconds (0.9345333666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 63)
# Ran iteration 63 in 203.638117 seconds (3.3939686166666667 minutes)
# Starting iteration #64
# Building zones with a target population of 4000 individuals
# Built zones in 75.393774 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.213097 seconds (0.9368849499999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 64)
# Ran iteration 64 in 203.827572 seconds (3.3971262 minutes)
# Starting iteration #65
# Building zones with a target population of 4000 individuals
# Built zones in 76.105616 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.162792 seconds (0.9360465333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 65)
# Ran iteration 65 in 204.573991 seconds (3.4095665166666667 minutes)
# Starting iteration #66
# Building zones with a target population of 4000 individuals
# Built zones in 78.303339 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.943295 seconds (0.9490549166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 66)
# Ran iteration 66 in 208.914394 seconds (3.4819065666666664 minutes)
# Starting iteration #67
# Building zones with a target population of 4000 individuals
# Built zones in 76.654998 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.526952 seconds (0.9421158666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 67)
# Ran iteration 67 in 206.112567 seconds (3.4352094500000003 minutes)
# Starting iteration #68
# Building zones with a target population of 4000 individuals
# Built zones in 76.99078 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.013418 seconds (0.9335569666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 68)
# Ran iteration 68 in 205.107359 seconds (3.4184559833333332 minutes)
# Starting iteration #69
# Building zones with a target population of 4000 individuals
# Built zones in 76.841823 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.162206 seconds (0.9360367666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 69)
# Ran iteration 69 in 205.339251 seconds (3.4223208499999997 minutes)
# Starting iteration #70
# Building zones with a target population of 4000 individuals
# Built zones in 77.155068 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.848971 seconds (0.9308161833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 70)
# Ran iteration 70 in 206.18269 seconds (3.4363781666666666 minutes)
# Starting iteration #71
# Building zones with a target population of 4000 individuals
# Built zones in 77.810711 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.256769 seconds (0.9376128166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 71)
# Ran iteration 71 in 206.601423 seconds (3.4433570500000004 minutes)
# Starting iteration #72
# Building zones with a target population of 4000 individuals
# Built zones in 77.640767 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.519447 seconds (0.9419907833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 72)
# Ran iteration 72 in 206.251439 seconds (3.4375239833333335 minutes)
# Starting iteration #73
# Building zones with a target population of 4000 individuals
# Built zones in 78.403571 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.078943 seconds (0.9346490500000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 73)
# Ran iteration 73 in 207.072448 seconds (3.451207466666667 minutes)
# Starting iteration #74
# Building zones with a target population of 4000 individuals
# Built zones in 77.50776 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.093399 seconds (0.9348899833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 74)
# Ran iteration 74 in 205.902444 seconds (3.4317074 minutes)
# Starting iteration #75
# Building zones with a target population of 4000 individuals
# Built zones in 78.241055 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.621975 seconds (0.9436995833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 75)
# Ran iteration 75 in 206.991156 seconds (3.4498526 minutes)
# Starting iteration #76
# Building zones with a target population of 4000 individuals
# Built zones in 78.464228 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.077308 seconds (0.9346218000000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 76)
# Ran iteration 76 in 207.12426 seconds (3.4520709999999997 minutes)
# Starting iteration #77
# Building zones with a target population of 4000 individuals
# Built zones in 78.892166 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.086095 seconds (0.93476825 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 77)
# Ran iteration 77 in 207.595179 seconds (3.4599196500000002 minutes)
# Starting iteration #78
# Building zones with a target population of 4000 individuals
# Built zones in 78.626647 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.576011 seconds (0.9429335166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 78)
# Ran iteration 78 in 207.361931 seconds (3.4560321833333334 minutes)
# Starting iteration #79
# Building zones with a target population of 4000 individuals
# Built zones in 79.241805 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.030209 seconds (0.9338368166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 79)
# Ran iteration 79 in 207.343729 seconds (3.4557288166666664 minutes)
# Starting iteration #80
# Building zones with a target population of 4000 individuals
# Built zones in 79.053956 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.162949 seconds (0.93604915 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 80)
# Ran iteration 80 in 207.123152 seconds (3.4520525333333336 minutes)
# Starting iteration #81
# Building zones with a target population of 4000 individuals
# Built zones in 79.357937 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.916381 seconds (0.9319396833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 81)
# Ran iteration 81 in 207.893281 seconds (3.464888016666667 minutes)
# Starting iteration #82
# Building zones with a target population of 4000 individuals
# Built zones in 79.49354 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.46846 seconds (0.941141 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 82)
# Ran iteration 82 in 208.203552 seconds (3.4700592 minutes)
# Starting iteration #83
# Building zones with a target population of 4000 individuals
# Built zones in 80.287723 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.327075 seconds (0.9387845833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 83)
# Ran iteration 83 in 209.010174 seconds (3.4835029 minutes)
# Starting iteration #84
# Building zones with a target population of 4000 individuals
# Built zones in 81.218549 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.737185 seconds (0.94561975 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 84)
# Ran iteration 84 in 210.946553 seconds (3.5157758833333332 minutes)
# Starting iteration #85
# Building zones with a target population of 4000 individuals
# Built zones in 80.214311 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.320127 seconds (0.9386687833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 85)
# Ran iteration 85 in 209.908645 seconds (3.498477416666667 minutes)
# Starting iteration #86
# Building zones with a target population of 4000 individuals
# Built zones in 80.935599 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.496641 seconds (0.9416106833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 86)
# Ran iteration 86 in 210.058617 seconds (3.50097695 minutes)
# Starting iteration #87
# Building zones with a target population of 4000 individuals
# Built zones in 80.697343 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.252902 seconds (0.9375483666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 87)
# Ran iteration 87 in 209.493264 seconds (3.4915544 minutes)
# Starting iteration #88
# Building zones with a target population of 4000 individuals
# Built zones in 81.363203 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.316655 seconds (0.9386109166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 88)
# Ran iteration 88 in 210.035187 seconds (3.50058645 minutes)
# Starting iteration #89
# Building zones with a target population of 4000 individuals
# Built zones in 81.311825 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.169768 seconds (0.9361628 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 89)
# Ran iteration 89 in 210.021611 seconds (3.5003601833333335 minutes)
# Starting iteration #90
# Building zones with a target population of 4000 individuals
# Built zones in 81.144819 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.686213 seconds (0.9447702166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 90)
# Ran iteration 90 in 210.26227 seconds (3.5043711666666666 minutes)
# Starting iteration #91
# Building zones with a target population of 4000 individuals
# Built zones in 81.994274 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.047334 seconds (0.9341222333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 91)
# Ran iteration 91 in 210.578385 seconds (3.50963975 minutes)
# Starting iteration #92
# Building zones with a target population of 4000 individuals
# Built zones in 81.880113 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.161403 seconds (0.9360233833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 92)
# Ran iteration 92 in 210.803303 seconds (3.5133883833333335 minutes)
# Starting iteration #93
# Building zones with a target population of 4000 individuals
# Built zones in 82.346127 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.388304 seconds (0.9398050666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 93)
# Ran iteration 93 in 211.483066 seconds (3.524717766666667 minutes)
# Starting iteration #94
# Building zones with a target population of 4000 individuals
# Built zones in 82.089166 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.152149 seconds (0.93586915 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 94)
# Ran iteration 94 in 211.073572 seconds (3.5178928666666667 minutes)
# Starting iteration #95
# Building zones with a target population of 4000 individuals
# Built zones in 82.33001 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.239242 seconds (0.9373207 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 95)
# Ran iteration 95 in 211.141908 seconds (3.5190318 minutes)
# Starting iteration #96
# Building zones with a target population of 4000 individuals
# Built zones in 84.449863 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.175258 seconds (0.9362543 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 96)
# Ran iteration 96 in 214.067483 seconds (3.5677913833333337 minutes)
# Starting iteration #97
# Building zones with a target population of 4000 individuals
# Built zones in 83.359267 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.031411 seconds (0.93385685 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 97)
# Ran iteration 97 in 212.469652 seconds (3.5411608666666665 minutes)
# Starting iteration #98
# Building zones with a target population of 4000 individuals
# Built zones in 83.256468 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.320558 seconds (0.9386759666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 98)
# Ran iteration 98 in 212.104119 seconds (3.53506865 minutes)
# Starting iteration #99
# Building zones with a target population of 4000 individuals
# Built zones in 83.849904 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.683988 seconds (0.9447331333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 99)
# Ran iteration 99 in 213.14096 seconds (3.5523493333333334 minutes)
# Done with all simulations! Time elapsed: 5:44:00.604932

# %% [markdown]
# ## Statistics for Simulation with 100 iterations, 4,000 target pop
# All statistics here were calculated on the RTI synthetic incomes dataset, limited to point features within the boundary of Hennepin County, MN. We ran our simulated "build balanced zones" with 100 iterations, each iteration building zones with a goal of 4,000 total population and a secondary goal of dense collections of census blocks per zone (aka "Compaction"). The basic units in constructing these zones were census blocks. After zones were constructed, income point features were spatially joined to their respective zones and the mean income was calculated. For each iteration, six income inequality measures were calculated. Here we focus solely on Gini. The distribution of Gini indexes across the full simulation is as follows:
#
# - Avg Gini:	0.20262972
# - Stdev Gini:	0.001712671
# - Min Gini:	0.198333698
# - Max Gini:	0.205906122
#
# When calculating Gini on real census tracts averages, it was **0.218685**, higher than the max Gini we found in our simulation. The simulation seems to show that census tracts are abnormally defined, tending to group households of similar income levels together. On the other hand, zones generated using only metrics of similar population and preferring dense, globular clusters tend to represent a more complete distribution of incomes within their bounds, resulting in a lower overall Gini value when differences between average zonal income are summarised.
#
# The quantification of how abnormal census tracts are in terms of Gini outcomes will be explored next, by fitting a distribution to the simulated results. Similar tests will be performed on the other income statistics. In addition to showing that the census tracts of today are unlikely, our simulation distribution shows that under the population constraint Gini is relatively stable, with a standard deviation of less than 0.01. This variation is inconsequential when compared to the difference between Gini on ungrouped incomes and block averages, underlining the findings in the previous section. In addition, we will attempt to gain a better mathematical understanding of the Theil and Atkinson indexes based on their behavior in simulation.

# %%
matplotlib.rcParams['figure.figsize'] = (16.0, 12.0)
matplotlib.style.use('ggplot')


def fit_kernel_density(data, bandwidth=0.001):
    kernels = ['gaussian' 
               ,'tophat'
               ,'epanechnikov'
               ,'exponential'
               ,'linear'
               ,'cosine'
              ]
    bandwidths = np.linspace(bandwidth,0.1,100)
    kde = GridSearchCV(estimator = KernelDensity(),
                       param_grid = {
                           "kernel": kernels,
                           "bandwidth": bandwidths
                       }
                       #,cv=KFold(n_splits=len(data)) # do 10-fold CV because of our small dataset
                       #,cv=KFold(n_splits=10)
                       ,cv=RepeatedKFold(n_splits=10, n_repeats=5)
                      )
    kde.fit(data[:, None])
    print("Best fitting parameters: {0}".format(kde.best_params_))
    return(kde)
    

# Create models from data
def best_fit_distribution(data, bins=15, ax=None):
    """Model data by finding best fit distribution to data"""
    # Get histogram of original data
    y, x = np.histogram(data, bins=bins, density=True)
    x = (x + np.roll(x, -1))[:-1] / 2.0

    # Distributions to check
    DISTRIBUTIONS = [        
        st.alpha,st.anglit,st.arcsine,st.beta,st.betaprime,st.bradford,st.burr,st.cauchy,st.chi,st.chi2,st.cosine,
        st.dgamma,st.dweibull,st.erlang,st.expon,st.exponnorm,st.exponweib,st.exponpow,st.f,st.fatiguelife,st.fisk,
        st.foldcauchy,st.foldnorm,st.frechet_r,st.frechet_l,st.genlogistic,st.genpareto,st.gennorm,st.genexpon,
        st.genextreme,st.gausshyper,st.gamma,st.gengamma,st.genhalflogistic,st.gilbrat,st.gompertz,st.gumbel_r,
        st.gumbel_l,st.halfcauchy,st.halflogistic,st.halfnorm,st.halfgennorm,st.hypsecant,st.invgamma,st.invgauss,
        st.invweibull,st.johnsonsb,st.johnsonsu,st.ksone,st.kstwobign,st.laplace,st.levy,st.levy_l,st.levy_stable,
        st.logistic,st.loggamma,st.loglaplace,st.lognorm,st.lomax,st.maxwell,st.mielke,st.nakagami,st.ncx2,st.ncf,
        st.nct,st.norm,st.pareto,st.pearson3,st.powerlaw,st.powerlognorm,st.powernorm,st.rdist,st.reciprocal,
        st.rayleigh,st.rice,st.recipinvgauss,st.semicircular,st.t,st.triang,st.truncexpon,st.truncnorm,st.tukeylambda,
        st.uniform,st.vonmises,st.vonmises_line,st.wald,st.weibull_min,st.weibull_max,st.wrapcauchy
    ]

    # Best holders
    best_distribution = st.norm
    best_params = (0.0, 1.0)
    best_sse = np.inf

    # Estimate distribution parameters from data
    for distribution in DISTRIBUTIONS:

        # Try to fit the distribution
        try:
            # Ignore warnings from data that can't be fit
            with warnings.catch_warnings():
                warnings.filterwarnings('ignore')

                # fit dist to data
                params = distribution.fit(data)

                # Separate parts of parameters
                arg = params[:-2]
                loc = params[-2]
                scale = params[-1]

                # Calculate fitted PDF and error with fit in distribution
                pdf = distribution.pdf(x, loc=loc, scale=scale, *arg)
                sse = np.sum(np.power(y - pdf, 2.0))

                # if axis pass in add to plot
                try:
                    if ax:
                        pd.Series(pdf, x).plot(ax=ax)
                    end
                except Exception:
                    pass

                # identify if this distribution is better
                if best_sse > sse > 0:
                    best_distribution = distribution
                    best_params = params
                    best_sse = sse

        except Exception:
            pass

    return (best_distribution.name, best_params, best_sse)

def calc_p_value(best_fit_dist, params, census_measure):
    # Separate parts of parameters
    arg = params[:-2]
    loc = params[-2]
    scale = params[-1]
    
    # Try to fit the distribution
    try:
        # Ignore warnings from data that can't be fit
        with warnings.catch_warnings():
            warnings.filterwarnings('ignore')

            # Calculate fitted PDF and error with fit in distribution
            cum_dist = best_fit_dist.cdf(census_measure, loc=loc, scale=scale, *arg)
            survival = best_fit_dist.sf(census_measure, loc=loc, scale=scale, *arg)
        
    except Exceptpion:
        pass
    
    print("Left tail probability: {0:.6f}. Right tail probability: {1:.6f}".format(cum_dist, survival))
    res = {'left_tail_prob': cum_dist,
          'right_tail_prob': survival}
    return(res)


def make_pdf(dist, params, size=10000):
    """Generate distributions's Probability Distribution Function """

    # Separate parts of parameters
    arg = params[:-2]
    loc = params[-2]
    scale = params[-1]

    # Get sane start and end points of distribution
    start = dist.ppf(0.01, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.01, loc=loc, scale=scale)
    end = dist.ppf(0.99, *arg, loc=loc, scale=scale) if arg else dist.ppf(0.99, loc=loc, scale=scale)

    # Build PDF and turn into pandas Series
    x = np.linspace(start, end, size)
    y = dist.pdf(x, loc=loc, scale=scale, *arg)
    pdf = pd.Series(y, x)

    return pdf


def plot_and_fit_density(path_to_file, file_name, bins=15, sim_title="", column="gini"):    
    print("Reading results from simulation")
    path_to_csv = os.path.join(path_to_file, file_name)
    data = pd.read_csv(filepath_or_buffer=path_to_csv,
                                 header=0,
                                 index_col=0)
    sim_data = data[column]
    sim_data_mean = np.mean(sim_data)
    sim_data_stdev = np.std(sim_data)
    sim_data_min = np.amin(sim_data)
    sim_data_max = np.amax(sim_data)
    print("Statistic '" + column + "' has the following characteristics:\n\tMean: {0:.4f}\n\tStDev: {1:.4f}\n\tMin: {2:.4f}\n\tMax: {3:.4f}".format(
                sim_data_mean,
                sim_data_stdev,
                sim_data_min,
                sim_data_max)
         )
    
    
    # Plot for comparison
    plt.figure(figsize=(12,8))
    ax = sim_data.plot(kind='hist', 
                        bins=bins, 
                        density=True, 
                        alpha=0.5
                        #,color=plt.rcParams['axes.color_cycle'][1]
                       )
    
    # Save plot limits
    dataYLim = ax.get_ylim()
    
    # Find best fit distribution
    print("Finding best theoretical distribution fit...")
    best_fit_name, best_fit_params, best_sse = best_fit_distribution(sim_data, bins=bins, ax=ax)
    best_dist = getattr(st, best_fit_name)
    
    print("Best distribution for {0} with {1} bins is {2} (sse={3})".format(column, bins, best_dist.name, best_sse))
    
    # Update plots
    ax.set_ylim(dataYLim)
    ax.set_title(sim_title + " Simulation Results")
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')
    #plt.legend(loc='upper left')
    
    save_fig_path = os.path.join(path_to_file, column+"_bin"+str(bins)+"_all_densities.png")
    plt.savefig(save_fig_path)
    
    # Make PDF with best params 
    pdf_sample_size = 10000
    pdf = make_pdf(best_dist, best_fit_params, size=pdf_sample_size)
    
    # Display
    plt.figure(figsize=(12,8))
    ax = pdf.plot(lw=2, 
                  label='PDF', 
                  legend=True)
    sim_data.plot(kind='hist', 
              bins=bins, 
              density=True, 
              alpha=0.5, 
              label='Data', 
              legend=True, 
              ax=ax)
    
    param_names = (best_dist.shapes + ', loc, scale').split(', ') if best_dist.shapes else ['loc', 'scale']
    param_str = ', '.join(['{}={:0.2f}'.format(k,v) for k,v in zip(param_names, best_fit_params)])
    dist_str = '{}({})'.format(best_fit_name, param_str)
    
    ax.set_title("Empirical Results with Best Fit Distribution on " + str(bins) + " Bins\n" + dist_str)
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency in {:,}'.format(pdf_sample_size))
    save_fig_path = os.path.join(path_to_file, column+"_bin" + str(bins) + "_best_densities.png")
    plt.savefig(save_fig_path)
    
    return




def fit_kernel_density_from_file(path_to_file, file_name, bins=15, sim_title="", column="gini"):    
    print("Reading results from simulation")
    path_to_csv = os.path.join(path_to_file, file_name)
    data = pd.read_csv(filepath_or_buffer=path_to_csv,
                                 header=0,
                                 index_col=0)
    sim_data = data[column]
    sim_data_mean = np.mean(sim_data)
    sim_data_stdev = np.std(sim_data)
    sim_data_min = np.amin(sim_data)
    sim_data_max = np.amax(sim_data)
    print("Statistic '" + column + "' has the following characteristics:\n\tMean: {0:.4f}\n\tStDev: {1:.4f}\n\tMin: {2:.4f}\n\tMax: {3:.4f}".format(
                sim_data_mean,
                sim_data_stdev,
                sim_data_min,
                sim_data_max)
         )
    
    X = sim_data.to_numpy()
    
    # Find best fit distribution
    print("Finding best theoretical distribution fit...")
    res = fit_kernel_density(X, bandwidth=(sim_data_stdev*0.5))
    data_log_density_evals = res.best_estimator_.score_samples(X[:,None])
    regular_x = np.linspace(sim_data_min-(sim_data_stdev*1), sim_data_max+(sim_data_stdev*1), num=1000)
    regular_log_density_evals = res.best_estimator_.score_samples(regular_x[:,None])
    
    # concatenate estimates with data
    X = np.column_stack((X, np.exp(data_log_density_evals)))
    
    # Sort along inequality measurement from high to low
    X = X[np.argsort(X[:,0])]
    
    # Plot normalized histogram of data for comparison with density
    plt.figure(figsize=(12,8))
    fig, ax = plt.subplots()
    #hist_data, bin_edges = np.histogram(X[:,0], bins=bins, density=True)
    #hist_data = hist_data / np.sum(hist_data)
    #print(hist_data)
    #ax.bar(bin_edges[:-1], height=hist_data, width=1.0, bottom=0, align='edge')
    
    # Plot best estimate distribution
    ax.plot(X[:,0], X[:,1], color='blue', marker='o', linewidth=0, markersize=12, label="Simulation Data")
    ax.plot(regular_x, np.exp(regular_log_density_evals), color='gray', linewidth=2, label="Estimated Kernel Density")
    
    # Format figure
    ax.set_ylim(0, np.amax(X[:,1]) + (np.amax(X[:,1]) * 0.05))
    ax.set_xlim(sim_data_min-(sim_data_stdev*1), sim_data_max+(sim_data_stdev*1))
    ax.legend(loc='upper left')
    ax.set_title('Kernel Density Estimation of {0} Using Kernel "{1}" and bandwidth {2:0.4f}'.format(column, 
                                                                                                res.best_params_['kernel'],
                                                                                                res.best_params_['bandwidth']))
    
    # Save figure
    save_fig_path = os.path.join(path_to_file, column+ "_best_kde_plot.png")
    plt.savefig(save_fig_path)
    
    # Print results of density estimation - what estimator fit best, its score, its parameters
    print("Best estimator: {0}\nBest score: {1}\nBest params: {2}".format(res.best_estimator_, res.best_score_, res.best_params_))
    
    #print("Full Results:")
    #print(res.cv_results_)
    
    return

# %%
file_loc = 'C:\\Users\\alex\\Documents\\code\\maup_income_inequality\\maup_inequality\\outputs\\simulation_100_2000'
file_name = 'results.csv'
columns = ['gini', "theil_l", "theil_t", "atkinson_25", "atkinson_50", "atkinson_75"]
for col in columns:
    fit_kernel_density_from_file(file_loc, file_name, bins=12, sim_title="2,000 Target Pop", column=col)

file_loc = 'C:\\Users\\alex\\Documents\\code\\maup_income_inequality\\maup_inequality\\outputs\\simulation_100_4000'
for col in columns:
    fit_kernel_density_from_file(file_loc, file_name, bins=12, sim_title="4,000 Target Pop", column=col)
    
file_loc = 'C:\\Users\\alex\\Documents\\code\\maup_income_inequality\\maup_inequality\\outputs\\simulation_100_6000'
for col in columns:
    fit_kernel_density_from_file(file_loc, file_name, bins=12, sim_title="6,000 Target Pop", column=col)
# Out:
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.2121
# 	StDev: 0.0014
# 	Min: 0.2078
# 	Max: 0.2152
# Finding best theoretical distribution fit...
# C:\Users\alex\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\sklearn\model_selection\_search.py:788: RuntimeWarning: invalid value encountered in subtract
#   array_means[:, np.newaxis]) ** 2,
# Best fitting parameters: {'bandwidth': 0.0017105133518458813, 'kernel': 'epanechnikov'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.0017105133518458813,
#               breadth_first=True, kernel='epanechnikov', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 51.04190595974107
# Best params: {'bandwidth': 0.0017105133518458813, 'kernel': 'epanechnikov'}
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0763
# 	StDev: 0.0012
# 	Min: 0.0728
# 	Max: 0.0791
# Finding best theoretical distribution fit...
# C:\Users\alex\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\sklearn\model_selection\_search.py:788: RuntimeWarning: invalid value encountered in subtract
#   array_means[:, np.newaxis]) ** 2,
# Best fitting parameters: {'bandwidth': 0.0005972419502655995, 'kernel': 'gaussian'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.0005972419502655995,
#               breadth_first=True, kernel='gaussian', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 52.684785547906216
# Best params: {'bandwidth': 0.0005972419502655995, 'kernel': 'gaussian'}
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0703
# 	StDev: 0.0009
# 	Min: 0.0674
# 	Max: 0.0725
# Finding best theoretical distribution fit...
# C:\Users\alex\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\sklearn\model_selection\_search.py:788: RuntimeWarning: invalid value encountered in subtract
#   array_means[:, np.newaxis]) ** 2,
# Best fitting parameters: {'bandwidth': 0.00047462095156522113, 'kernel': 'gaussian'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.00047462095156522113,
#               breadth_first=True, kernel='gaussian', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 54.978776181020514
# Best params: {'bandwidth': 0.00047462095156522113, 'kernel': 'gaussian'}
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0178
# 	StDev: 0.0002
# 	Min: 0.0170
# 	Max: 0.0184
# Finding best theoretical distribution fit...
# C:\Users\alex\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\sklearn\model_selection\_search.py:788: RuntimeWarning: invalid value encountered in subtract
#   array_means[:, np.newaxis]) ** 2,
# Best fitting parameters: {'bandwidth': 0.00012266129570330232, 'kernel': 'gaussian'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.00012266129570330232,
#               breadth_first=True, kernel='gaussian', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 68.50661341981649
# Best params: {'bandwidth': 0.00012266129570330232, 'kernel': 'gaussian'}
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0360
# 	StDev: 0.0005
# 	Min: 0.0345
# 	Max: 0.0372
# Finding best theoretical distribution fit...
# C:\Users\alex\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\sklearn\model_selection\_search.py:788: RuntimeWarning: invalid value encountered in subtract
#   array_means[:, np.newaxis]) ** 2,
# Best fitting parameters: {'bandwidth': 0.00025444980931649513, 'kernel': 'gaussian'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.00025444980931649513,
#               breadth_first=True, kernel='gaussian', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 61.17289964945647
# Best params: {'bandwidth': 0.00025444980931649513, 'kernel': 'gaussian'}
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0546
# 	StDev: 0.0008
# 	Min: 0.0522
# 	Max: 0.0564
# Finding best theoretical distribution fit...
# C:\Users\alex\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\sklearn\model_selection\_search.py:788: RuntimeWarning: invalid value encountered in subtract
#   array_means[:, np.newaxis]) ** 2,
# Best fitting parameters: {'bandwidth': 0.00039727285169081916, 'kernel': 'gaussian'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.00039727285169081916,
#               breadth_first=True, kernel='gaussian', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 56.78715992503587
# Best params: {'bandwidth': 0.00039727285169081916, 'kernel': 'gaussian'}
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.2026
# 	StDev: 0.0017
# 	Min: 0.1983
# 	Max: 0.2059
# Finding best theoretical distribution fit...
# Best fitting parameters: {'bandwidth': 0.001857786455925525, 'kernel': 'linear'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.001857786455925525,
#               breadth_first=True, kernel='linear', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 49.32092803658098
# Best params: {'bandwidth': 0.001857786455925525, 'kernel': 'linear'}
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0694
# 	StDev: 0.0013
# 	Min: 0.0664
# 	Max: 0.0720
# Finding best theoretical distribution fit...
# Best fitting parameters: {'bandwidth': 0.0006580697958537538, 'kernel': 'tophat'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.0006580697958537538,
#               breadth_first=True, kernel='tophat', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 52.12811241839218
# Best params: {'bandwidth': 0.0006580697958537538, 'kernel': 'tophat'}
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0641
# 	StDev: 0.0011
# 	Min: 0.0616
# 	Max: 0.0663
# Finding best theoretical distribution fit...
# Best fitting parameters: {'bandwidth': 0.0005502952461797063, 'kernel': 'linear'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.0005502952461797063,
#               breadth_first=True, kernel='linear', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 53.706664713583415
# Best params: {'bandwidth': 0.0005502952461797063, 'kernel': 'linear'}
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0162
# 	StDev: 0.0003
# 	Min: 0.0156
# 	Max: 0.0168
# Finding best theoretical distribution fit...
# Best fitting parameters: {'bandwidth': 0.00014038254437494604, 'kernel': 'tophat'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.00014038254437494604,
#               breadth_first=True, kernel='tophat', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 67.49992257687356
# Best params: {'bandwidth': 0.00014038254437494604, 'kernel': 'tophat'}
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0328
# 	StDev: 0.0006
# 	Min: 0.0315
# 	Max: 0.0340
# Finding best theoretical distribution fit...
# Best fitting parameters: {'bandwidth': 0.0002878257514876392, 'kernel': 'epanechnikov'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.0002878257514876392,
#               breadth_first=True, kernel='epanechnikov', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 60.20601141912597
# Best params: {'bandwidth': 0.0002878257514876392, 'kernel': 'epanechnikov'}
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0498
# 	StDev: 0.0009
# 	Min: 0.0477
# 	Max: 0.0515
# Finding best theoretical distribution fit...
# Best fitting parameters: {'bandwidth': 0.00044476961750273994, 'kernel': 'tophat'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.00044476961750273994,
#               breadth_first=True, kernel='tophat', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 55.96417550675383
# Best params: {'bandwidth': 0.00044476961750273994, 'kernel': 'tophat'}
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.1962
# 	StDev: 0.0017
# 	Min: 0.1923
# 	Max: 0.2003
# Finding best theoretical distribution fit...
# Best fitting parameters: {'bandwidth': 0.0018506046775747626, 'kernel': 'epanechnikov'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.0018506046775747626,
#               breadth_first=True, kernel='epanechnikov', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 49.30548147899818
# Best params: {'bandwidth': 0.0018506046775747626, 'kernel': 'epanechnikov'}
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0648
# 	StDev: 0.0013
# 	Min: 0.0622
# 	Max: 0.0686
# Finding best theoretical distribution fit...
# C:\Users\alex\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\sklearn\model_selection\_search.py:788: RuntimeWarning: invalid value encountered in subtract
#   array_means[:, np.newaxis]) ** 2,
# Best fitting parameters: {'bandwidth': 0.0016584258174875302, 'kernel': 'cosine'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.0016584258174875302,
#               breadth_first=True, kernel='cosine', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 51.82634430666365
# Best params: {'bandwidth': 0.0016584258174875302, 'kernel': 'cosine'}
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0601
# 	StDev: 0.0011
# 	Min: 0.0578
# 	Max: 0.0627
# Finding best theoretical distribution fit...
# Best fitting parameters: {'bandwidth': 0.0005322499545133504, 'kernel': 'tophat'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.0005322499545133504,
#               breadth_first=True, kernel='tophat', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 53.95231097622677
# Best params: {'bandwidth': 0.0005322499545133504, 'kernel': 'tophat'}
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0152
# 	StDev: 0.0003
# 	Min: 0.0146
# 	Max: 0.0159
# Finding best theoretical distribution fit...
# C:\Users\alex\AppData\Local\ESRI\conda\envs\arcgispro-py3-clone\lib\site-packages\sklearn\model_selection\_search.py:788: RuntimeWarning: invalid value encountered in subtract
#   array_means[:, np.newaxis]) ** 2,
# Best fitting parameters: {'bandwidth': 0.0001366009001476697, 'kernel': 'gaussian'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.0001366009001476697,
#               breadth_first=True, kernel='gaussian', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 67.48137538400381
# Best params: {'bandwidth': 0.0001366009001476697, 'kernel': 'gaussian'}
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0308
# 	StDev: 0.0006
# 	Min: 0.0296
# 	Max: 0.0323
# Finding best theoretical distribution fit...
# Best fitting parameters: {'bandwidth': 0.00028215067750690475, 'kernel': 'gaussian'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.00028215067750690475,
#               breadth_first=True, kernel='gaussian', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 60.20704639109038
# Best params: {'bandwidth': 0.00028215067750690475, 'kernel': 'gaussian'}
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0466
# 	StDev: 0.0009
# 	Min: 0.0449
# 	Max: 0.0491
# Finding best theoretical distribution fit...
# Best fitting parameters: {'bandwidth': 0.0004399056688086999, 'kernel': 'gaussian'}
# __main__:253: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# __main__:254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Best estimator: KernelDensity(algorithm='auto', atol=0, bandwidth=0.0004399056688086999,
#               breadth_first=True, kernel='gaussian', leaf_size=40,
#               metric='euclidean', metric_params=None, rtol=0)
# Best score: 55.87466705130285
# Best params: {'bandwidth': 0.0004399056688086999, 'kernel': 'gaussian'}

# %%
statistics_to_iterate = ["gini", "theil_l", "theil_t", "atkinson_25", "atkinson_50", "atkinson_75"]
bins_to_iterate = [20, 17, 15, 12, 10]

for stat in statistics_to_iterate:
    for binsize in bins_to_iterate:
        plot_and_fit_density(file_loc, file_name, bins=binsize, sim_title="4,000 Target Pop", column=stat)
# Out:
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.2026
# 	StDev: 0.0017
# 	Min: 0.1983
# 	Max: 0.2059
# Finding best theoretical distribution fit...
# Best distribution for gini with 20 bins is dgamma (sse=40255.107411310826)
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.2026
# 	StDev: 0.0017
# 	Min: 0.1983
# 	Max: 0.2059
# Finding best theoretical distribution fit...
# Best distribution for gini with 17 bins is dgamma (sse=27167.86491571979)
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.2026
# 	StDev: 0.0017
# 	Min: 0.1983
# 	Max: 0.2059
# Finding best theoretical distribution fit...
# Best distribution for gini with 15 bins is dgamma (sse=27039.285787324083)
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.2026
# 	StDev: 0.0017
# 	Min: 0.1983
# 	Max: 0.2059
# Finding best theoretical distribution fit...
# Best distribution for gini with 12 bins is dgamma (sse=15318.051969174756)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.2026
# 	StDev: 0.0017
# 	Min: 0.1983
# 	Max: 0.2059
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for gini with 10 bins is pearson3 (sse=5155.36448688351)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0694
# 	StDev: 0.0013
# 	Min: 0.0664
# 	Max: 0.0720
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_l with 20 bins is triang (sse=85866.48483107021)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0694
# 	StDev: 0.0013
# 	Min: 0.0664
# 	Max: 0.0720
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_l with 17 bins is triang (sse=30449.17044256405)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0694
# 	StDev: 0.0013
# 	Min: 0.0664
# 	Max: 0.0720
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_l with 15 bins is triang (sse=59690.729572644734)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0694
# 	StDev: 0.0013
# 	Min: 0.0664
# 	Max: 0.0720
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_l with 12 bins is triang (sse=25899.198248942008)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0694
# 	StDev: 0.0013
# 	Min: 0.0664
# 	Max: 0.0720
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_l with 10 bins is triang (sse=9753.110709788945)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0641
# 	StDev: 0.0011
# 	Min: 0.0616
# 	Max: 0.0663
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_t with 20 bins is dweibull (sse=152939.02164978415)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0641
# 	StDev: 0.0011
# 	Min: 0.0616
# 	Max: 0.0663
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_t with 17 bins is dgamma (sse=50928.10597130248)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0641
# 	StDev: 0.0011
# 	Min: 0.0616
# 	Max: 0.0663
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_t with 15 bins is dweibull (sse=99184.02439099133)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0641
# 	StDev: 0.0011
# 	Min: 0.0616
# 	Max: 0.0663
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_t with 12 bins is dgamma (sse=25952.296670300893)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0641
# 	StDev: 0.0011
# 	Min: 0.0616
# 	Max: 0.0663
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_t with 10 bins is dgamma (sse=28747.490921585788)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0162
# 	StDev: 0.0003
# 	Min: 0.0156
# 	Max: 0.0168
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_25 with 20 bins is dweibull (sse=2164578.143644262)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0162
# 	StDev: 0.0003
# 	Min: 0.0156
# 	Max: 0.0168
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_25 with 17 bins is dweibull (sse=966672.2182881916)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0162
# 	StDev: 0.0003
# 	Min: 0.0156
# 	Max: 0.0168
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_25 with 15 bins is dweibull (sse=1372244.0404204652)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0162
# 	StDev: 0.0003
# 	Min: 0.0156
# 	Max: 0.0168
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_25 with 12 bins is triang (sse=420749.2997007256)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0162
# 	StDev: 0.0003
# 	Min: 0.0156
# 	Max: 0.0168
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_25 with 10 bins is dweibull (sse=412689.6745484168)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0328
# 	StDev: 0.0006
# 	Min: 0.0315
# 	Max: 0.0340
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_50 with 20 bins is pearson3 (sse=438006.8862418263)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0328
# 	StDev: 0.0006
# 	Min: 0.0315
# 	Max: 0.0340
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_50 with 17 bins is dgamma (sse=336341.6118263398)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0328
# 	StDev: 0.0006
# 	Min: 0.0315
# 	Max: 0.0340
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_50 with 15 bins is dweibull (sse=267650.9927609702)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0328
# 	StDev: 0.0006
# 	Min: 0.0315
# 	Max: 0.0340
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_50 with 12 bins is dweibull (sse=143716.34700783316)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0328
# 	StDev: 0.0006
# 	Min: 0.0315
# 	Max: 0.0340
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_50 with 10 bins is dweibull (sse=108359.22512933075)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0498
# 	StDev: 0.0009
# 	Min: 0.0477
# 	Max: 0.0515
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_75 with 20 bins is dweibull (sse=149487.915322848)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0498
# 	StDev: 0.0009
# 	Min: 0.0477
# 	Max: 0.0515
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_75 with 17 bins is dweibull (sse=81122.3082747993)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0498
# 	StDev: 0.0009
# 	Min: 0.0477
# 	Max: 0.0515
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_75 with 15 bins is dweibull (sse=80792.45314728195)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0498
# 	StDev: 0.0009
# 	Min: 0.0477
# 	Max: 0.0515
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_75 with 12 bins is dweibull (sse=31931.220292506845)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0498
# 	StDev: 0.0009
# 	Min: 0.0477
# 	Max: 0.0515
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_75 with 10 bins is dweibull (sse=40797.45603017629)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# ![Density for 4,000 target pop](\\outputs\\simulation_100_4000\\gini_bin10_best_densities.png)

# %%
Run_Simulation(num_iterations=100, pop_target=2000, zone_characteristic_goal='COMPACTNESS', continue_from_failure=True, resume_iter=70)
# Out:
# Continuing simulation with 100 iterations, starting from iteration 70. Zones will be built with population goals of 2000 and zone characteristic COMPACTNESS
# Starting iteration #70
# Building zones with a target population of 2000 individuals
# Built zones in 73.81881 seconds.
# Applying zones to point features...
# Assigned income points to zones in 52.007103 seconds (0.8667850500000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 70)
# Ran iteration 70 in 199.551901 seconds (3.3258650166666666 minutes)
# Starting iteration #71
# Building zones with a target population of 2000 individuals
# Built zones in 68.935148 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.87909 seconds (0.8646515 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 71)
# Ran iteration 71 in 188.388259 seconds (3.139804316666667 minutes)
# Starting iteration #72
# Building zones with a target population of 2000 individuals
# Built zones in 70.306668 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.700173 seconds (0.86166955 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 72)
# Ran iteration 72 in 189.77061 seconds (3.1628435 minutes)
# Starting iteration #73
# Building zones with a target population of 2000 individuals
# Built zones in 74.192937 seconds.
# Applying zones to point features...
# Assigned income points to zones in 52.829262 seconds (0.8804877 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 73)
# Ran iteration 73 in 195.35873 seconds (3.2559788333333333 minutes)
# Starting iteration #74
# Building zones with a target population of 2000 individuals
# Built zones in 74.839666 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.731038 seconds (0.8621839666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 74)
# Ran iteration 74 in 195.312876 seconds (3.2552146 minutes)
# Starting iteration #75
# Building zones with a target population of 2000 individuals
# Built zones in 74.278276 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.896356 seconds (0.8649392666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 75)
# Ran iteration 75 in 193.929545 seconds (3.2321590833333333 minutes)
# Starting iteration #76
# Building zones with a target population of 2000 individuals
# Built zones in 71.695273 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.902083 seconds (0.8650347166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 76)
# Ran iteration 76 in 191.804946 seconds (3.1967491 minutes)
# Starting iteration #77
# Building zones with a target population of 2000 individuals
# Built zones in 73.332765 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.808291 seconds (0.8634715166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 77)
# Ran iteration 77 in 193.009994 seconds (3.2168332333333334 minutes)
# Starting iteration #78
# Building zones with a target population of 2000 individuals
# Built zones in 75.469014 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.759244 seconds (0.8626540666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 78)
# Ran iteration 78 in 195.262402 seconds (3.254373366666667 minutes)
# Starting iteration #79
# Building zones with a target population of 2000 individuals
# Built zones in 74.344716 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.638079 seconds (0.86063465 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 79)
# Ran iteration 79 in 193.866632 seconds (3.2311105333333336 minutes)
# Starting iteration #80
# Building zones with a target population of 2000 individuals
# Built zones in 76.529196 seconds.
# Applying zones to point features...
# Assigned income points to zones in 52.054584 seconds (0.8675764 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 80)
# Ran iteration 80 in 196.646167 seconds (3.2774361166666663 minutes)
# Starting iteration #81
# Building zones with a target population of 2000 individuals
# Built zones in 86.787653 seconds.
# Applying zones to point features...
# Assigned income points to zones in 52.594156 seconds (0.8765692666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 81)
# Ran iteration 81 in 206.543782 seconds (3.4423963666666664 minutes)
# Starting iteration #82
# Building zones with a target population of 2000 individuals
# Built zones in 76.963205 seconds.
# Applying zones to point features...
# Assigned income points to zones in 52.705067 seconds (0.8784177833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 82)
# Ran iteration 82 in 197.028899 seconds (3.2838149833333334 minutes)
# Starting iteration #83
# Building zones with a target population of 2000 individuals
# Built zones in 72.538762 seconds.
# Applying zones to point features...
# Assigned income points to zones in 52.428768 seconds (0.8738128 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 83)
# Ran iteration 83 in 192.641563 seconds (3.2106927166666663 minutes)
# Starting iteration #84
# Building zones with a target population of 2000 individuals
# Built zones in 72.005193 seconds.
# Applying zones to point features...
# Assigned income points to zones in 52.331632 seconds (0.8721938666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 84)
# Ran iteration 84 in 192.183977 seconds (3.2030662833333334 minutes)
# Starting iteration #85
# Building zones with a target population of 2000 individuals
# Built zones in 79.716622 seconds.
# Applying zones to point features...
# Assigned income points to zones in 52.410329 seconds (0.8735054833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 85)
# Ran iteration 85 in 200.074869 seconds (3.33458115 minutes)
# Starting iteration #86
# Building zones with a target population of 2000 individuals
# Built zones in 81.300981 seconds.
# Applying zones to point features...
# Assigned income points to zones in 52.826299 seconds (0.8804383166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 86)
# Ran iteration 86 in 201.759786 seconds (3.3626631 minutes)
# Starting iteration #87
# Building zones with a target population of 2000 individuals
# Built zones in 93.243574 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.763035 seconds (0.86271725 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 87)
# Ran iteration 87 in 212.688206 seconds (3.5448034333333336 minutes)
# Starting iteration #88
# Building zones with a target population of 2000 individuals
# Built zones in 81.94022 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.945746 seconds (0.8657624333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 88)
# Ran iteration 88 in 202.917976 seconds (3.3819662666666668 minutes)
# Starting iteration #89
# Building zones with a target population of 2000 individuals
# Built zones in 83.138294 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.801005 seconds (0.8633500833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 89)
# Ran iteration 89 in 203.350428 seconds (3.3891738 minutes)
# Starting iteration #90
# Building zones with a target population of 2000 individuals
# Built zones in 84.820565 seconds.
# Applying zones to point features...
# Assigned income points to zones in 52.653197 seconds (0.8775532833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 90)
# Ran iteration 90 in 206.155108 seconds (3.4359184666666667 minutes)
# Starting iteration #91
# Building zones with a target population of 2000 individuals
# Built zones in 84.05375 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.845352 seconds (0.8640892 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 91)
# Ran iteration 91 in 203.076862 seconds (3.384614366666667 minutes)
# Starting iteration #92
# Building zones with a target population of 2000 individuals
# Built zones in 104.77607 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.991624 seconds (0.8665270666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 92)
# Ran iteration 92 in 225.89582 seconds (3.764930333333333 minutes)
# Starting iteration #93
# Building zones with a target population of 2000 individuals
# Built zones in 87.272643 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.996779 seconds (0.8666129833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 93)
# Ran iteration 93 in 208.771107 seconds (3.47951845 minutes)
# Starting iteration #94
# Building zones with a target population of 2000 individuals
# Built zones in 92.184786 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.69141 seconds (1.0115235 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 94)
# Ran iteration 94 in 232.494455 seconds (3.874907583333333 minutes)
# Starting iteration #95
# Building zones with a target population of 2000 individuals
# Built zones in 88.733271 seconds.
# Applying zones to point features...
# Assigned income points to zones in 53.315263 seconds (0.8885877166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 95)
# Ran iteration 95 in 209.156905 seconds (3.4859484166666665 minutes)
# Starting iteration #96
# Building zones with a target population of 2000 individuals
# Built zones in 88.856339 seconds.
# Applying zones to point features...
# Assigned income points to zones in 51.960745 seconds (0.8660124166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 96)
# Ran iteration 96 in 210.237479 seconds (3.5039579833333336 minutes)
# Starting iteration #97
# Building zones with a target population of 2000 individuals
# Built zones in 90.400582 seconds.
# Applying zones to point features...
# Assigned income points to zones in 52.339997 seconds (0.8723332833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 97)
# Ran iteration 97 in 211.884921 seconds (3.53141535 minutes)
# Starting iteration #98
# Building zones with a target population of 2000 individuals
# Built zones in 91.50042 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.413913 seconds (0.9735652166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 98)
# Ran iteration 98 in 217.756598 seconds (3.6292766333333333 minutes)
# Starting iteration #99
# Building zones with a target population of 2000 individuals
# Built zones in 93.156449 seconds.
# Applying zones to point features...
# Assigned income points to zones in 54.367316 seconds (0.9061219333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 99)
# Ran iteration 99 in 259.951024 seconds (4.332517066666667 minutes)
# Done with all simulations! Time elapsed: 1:42:07.486736

# %% [markdown]
# ## Statistics for Simulation with 100 iterations, 2,000 target pop
# - Mean Gini:	0.212107861
# - StDev Gini:	0.001415119
# - Min Gini:	0.207757523
# - Max Gini:	0.215213073

# %%
file_loc = 'C:\\Users\\alex\\Documents\\code\\maup_income_inequality\\maup_inequality\\outputs\\simulation_100_2000'
file_name = 'results.csv'
statistics_to_iterate = ["gini", "theil_l", "theil_t", "atkinson_25", "atkinson_50", "atkinson_75"]
bins_to_iterate = [20, 17, 15, 12, 10]

for stat in statistics_to_iterate:
    for binsize in bins_to_iterate:
        plot_and_fit_density(file_loc, file_name, bins=binsize, sim_title="2,000 Target Pop", column=stat)
# Out:
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.2121
# 	StDev: 0.0014
# 	Min: 0.2078
# 	Max: 0.2152
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for gini with 20 bins is dweibull (sse=40337.169935630765)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.2121
# 	StDev: 0.0014
# 	Min: 0.2078
# 	Max: 0.2152
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for gini with 17 bins is dweibull (sse=19319.926234700346)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.2121
# 	StDev: 0.0014
# 	Min: 0.2078
# 	Max: 0.2152
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for gini with 15 bins is dgamma (sse=14685.232886495482)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.2121
# 	StDev: 0.0014
# 	Min: 0.2078
# 	Max: 0.2152
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for gini with 12 bins is mielke (sse=10558.652389318631)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'gini' has the following characteristics:
# 	Mean: 0.2121
# 	StDev: 0.0014
# 	Min: 0.2078
# 	Max: 0.2152
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for gini with 10 bins is levy_stable (sse=4209.9359955788705)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0763
# 	StDev: 0.0012
# 	Min: 0.0728
# 	Max: 0.0791
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_l with 20 bins is gamma (sse=69272.01093898721)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0763
# 	StDev: 0.0012
# 	Min: 0.0728
# 	Max: 0.0791
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_l with 17 bins is dweibull (sse=58138.536626384914)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0763
# 	StDev: 0.0012
# 	Min: 0.0728
# 	Max: 0.0791
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_l with 15 bins is dweibull (sse=36527.57576365726)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0763
# 	StDev: 0.0012
# 	Min: 0.0728
# 	Max: 0.0791
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_l with 12 bins is dweibull (sse=13513.861681769828)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_l' has the following characteristics:
# 	Mean: 0.0763
# 	StDev: 0.0012
# 	Min: 0.0728
# 	Max: 0.0791
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_l with 10 bins is dweibull (sse=10296.101169454461)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0703
# 	StDev: 0.0009
# 	Min: 0.0674
# 	Max: 0.0725
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_t with 20 bins is dweibull (sse=74366.52378941097)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0703
# 	StDev: 0.0009
# 	Min: 0.0674
# 	Max: 0.0725
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_t with 17 bins is dweibull (sse=29210.13512225782)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0703
# 	StDev: 0.0009
# 	Min: 0.0674
# 	Max: 0.0725
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_t with 15 bins is dweibull (sse=50762.140974421)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0703
# 	StDev: 0.0009
# 	Min: 0.0674
# 	Max: 0.0725
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_t with 12 bins is dweibull (sse=26224.99118100817)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'theil_t' has the following characteristics:
# 	Mean: 0.0703
# 	StDev: 0.0009
# 	Min: 0.0674
# 	Max: 0.0725
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for theil_t with 10 bins is dgamma (sse=4575.458371104789)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0178
# 	StDev: 0.0002
# 	Min: 0.0170
# 	Max: 0.0184
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_25 with 20 bins is dgamma (sse=1308533.9382094047)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0178
# 	StDev: 0.0002
# 	Min: 0.0170
# 	Max: 0.0184
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_25 with 17 bins is dweibull (sse=1013160.5877410093)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0178
# 	StDev: 0.0002
# 	Min: 0.0170
# 	Max: 0.0184
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_25 with 15 bins is dgamma (sse=1142604.3448204119)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0178
# 	StDev: 0.0002
# 	Min: 0.0170
# 	Max: 0.0184
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_25 with 12 bins is dweibull (sse=421485.28451702616)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_25' has the following characteristics:
# 	Mean: 0.0178
# 	StDev: 0.0002
# 	Min: 0.0170
# 	Max: 0.0184
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_25 with 10 bins is dweibull (sse=204158.41144329213)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0360
# 	StDev: 0.0005
# 	Min: 0.0345
# 	Max: 0.0372
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_50 with 20 bins is dgamma (sse=323950.02282732766)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0360
# 	StDev: 0.0005
# 	Min: 0.0345
# 	Max: 0.0372
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_50 with 17 bins is dweibull (sse=196386.41572149604)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0360
# 	StDev: 0.0005
# 	Min: 0.0345
# 	Max: 0.0372
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_50 with 15 bins is dweibull (sse=257581.2448238914)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0360
# 	StDev: 0.0005
# 	Min: 0.0345
# 	Max: 0.0372
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_50 with 12 bins is dweibull (sse=63044.88307841437)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_50' has the following characteristics:
# 	Mean: 0.0360
# 	StDev: 0.0005
# 	Min: 0.0345
# 	Max: 0.0372
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_50 with 10 bins is dgamma (sse=73049.12176093788)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0546
# 	StDev: 0.0008
# 	Min: 0.0522
# 	Max: 0.0564
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_75 with 20 bins is dweibull (sse=152520.54193808837)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0546
# 	StDev: 0.0008
# 	Min: 0.0522
# 	Max: 0.0564
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_75 with 17 bins is dgamma (sse=110155.3202431443)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0546
# 	StDev: 0.0008
# 	Min: 0.0522
# 	Max: 0.0564
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_75 with 15 bins is dweibull (sse=51757.06879532273)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0546
# 	StDev: 0.0008
# 	Min: 0.0522
# 	Max: 0.0564
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_75 with 12 bins is dweibull (sse=26714.35803836606)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Reading results from simulation
# Statistic 'atkinson_75' has the following characteristics:
# 	Mean: 0.0546
# 	StDev: 0.0008
# 	Min: 0.0522
# 	Max: 0.0564
# __main__:109: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# Finding best theoretical distribution fit...
# Best distribution for atkinson_75 with 10 bins is dweibull (sse=19347.377762246557)
# __main__:142: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
Run_Simulation(num_iterations=100, pop_target=6000, zone_characteristic_goal='COMPACTNESS')
# Out:
# Starting simulation with 100 iterations. Zones will be built with population goals of 6000 and zone characteristic COMPACTNESS
# Starting iteration #0
# Building zones with a target population of 6000 individuals
# Built zones in 76.015951 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.986467 seconds (1.0831077833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 0)
# Ran iteration 0 in 225.568911 seconds (3.7594818500000002 minutes)
# Starting iteration #1
# Building zones with a target population of 6000 individuals
# Built zones in 73.848106 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.280372 seconds (1.0713395333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 1)
# Ran iteration 1 in 220.959952 seconds (3.6826658666666665 minutes)
# Starting iteration #2
# Building zones with a target population of 6000 individuals
# Built zones in 72.566974 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.520549 seconds (1.0753424833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 2)
# Ran iteration 2 in 220.440772 seconds (3.6740128666666667 minutes)
# Starting iteration #3
# Building zones with a target population of 6000 individuals
# Built zones in 72.901649 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.233329 seconds (1.0538888166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 3)
# Ran iteration 3 in 218.285114 seconds (3.6380852333333333 minutes)
# Starting iteration #4
# Building zones with a target population of 6000 individuals
# Built zones in 77.285709 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.582308 seconds (1.0597051333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 4)
# Ran iteration 4 in 223.531705 seconds (3.7255284166666667 minutes)
# Starting iteration #5
# Building zones with a target population of 6000 individuals
# Built zones in 72.645703 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.308387 seconds (1.07180645 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 5)
# Ran iteration 5 in 218.96677 seconds (3.6494461666666664 minutes)
# Starting iteration #6
# Building zones with a target population of 6000 individuals
# Built zones in 73.148967 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.137423 seconds (1.0522903833333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 6)
# Ran iteration 6 in 219.272349 seconds (3.6545391499999997 minutes)
# Starting iteration #7
# Building zones with a target population of 6000 individuals
# Built zones in 73.247465 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.149339 seconds (1.06915565 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 7)
# Ran iteration 7 in 221.253747 seconds (3.68756245 minutes)
# Starting iteration #8
# Building zones with a target population of 6000 individuals
# Built zones in 72.889589 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.428888 seconds (1.0904814666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 8)
# Ran iteration 8 in 232.780663 seconds (3.879677716666667 minutes)
# Starting iteration #9
# Building zones with a target population of 6000 individuals
# Built zones in 86.300395 seconds.
# Applying zones to point features...
# Assigned income points to zones in 71.216961 seconds (1.18694935 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 9)
# Ran iteration 9 in 241.114457 seconds (4.018574283333333 minutes)
# Starting iteration #10
# Building zones with a target population of 6000 individuals
# Built zones in 73.752873 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.114055 seconds (1.0519009166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 10)
# Ran iteration 10 in 219.625071 seconds (3.66041785 minutes)
# Starting iteration #11
# Building zones with a target population of 6000 individuals
# Built zones in 71.866406 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.653427 seconds (1.06089045 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 11)
# Ran iteration 11 in 218.556065 seconds (3.642601083333333 minutes)
# Starting iteration #12
# Building zones with a target population of 6000 individuals
# Built zones in 73.402754 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.119701 seconds (1.0686616833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 12)
# Ran iteration 12 in 218.75118 seconds (3.6458530000000002 minutes)
# Starting iteration #13
# Building zones with a target population of 6000 individuals
# Built zones in 73.350216 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.608253 seconds (1.0768042166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 13)
# Ran iteration 13 in 221.18609 seconds (3.6864348333333337 minutes)
# Starting iteration #14
# Building zones with a target population of 6000 individuals
# Built zones in 73.119436 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.72182 seconds (1.0786969999999998 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 14)
# Ran iteration 14 in 220.994416 seconds (3.6832402666666666 minutes)
# Starting iteration #15
# Building zones with a target population of 6000 individuals
# Built zones in 72.63321 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.705254 seconds (1.0617542333333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 15)
# Ran iteration 15 in 218.475887 seconds (3.6412647833333334 minutes)
# Starting iteration #16
# Building zones with a target population of 6000 individuals
# Built zones in 74.766253 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.699146 seconds (1.0616524333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 16)
# Ran iteration 16 in 221.775807 seconds (3.6962634499999996 minutes)
# Starting iteration #17
# Building zones with a target population of 6000 individuals
# Built zones in 75.408835 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.048692 seconds (1.0841448666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 17)
# Ran iteration 17 in 223.040199 seconds (3.71733665 minutes)
# Starting iteration #18
# Building zones with a target population of 6000 individuals
# Built zones in 73.719306 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.478734 seconds (1.0746455666666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 18)
# Ran iteration 18 in 221.451032 seconds (3.6908505333333332 minutes)
# Starting iteration #19
# Building zones with a target population of 6000 individuals
# Built zones in 72.951173 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.632664 seconds (1.0772110666666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 19)
# Ran iteration 19 in 220.201048 seconds (3.6700174666666663 minutes)
# Starting iteration #20
# Building zones with a target population of 6000 individuals
# Built zones in 72.790809 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.519052 seconds (1.0586508666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 20)
# Ran iteration 20 in 218.594569 seconds (3.6432428166666666 minutes)
# Starting iteration #21
# Building zones with a target population of 6000 individuals
# Built zones in 71.677803 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.833003 seconds (1.08055005 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 21)
# Ran iteration 21 in 219.448873 seconds (3.6574812166666666 minutes)
# Starting iteration #22
# Building zones with a target population of 6000 individuals
# Built zones in 75.772375 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.662426 seconds (1.0777071 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 22)
# Ran iteration 22 in 223.670748 seconds (3.7278458 minutes)
# Starting iteration #23
# Building zones with a target population of 6000 individuals
# Built zones in 75.947535 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.464242 seconds (1.0577373666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 23)
# Ran iteration 23 in 225.629248 seconds (3.7604874666666666 minutes)
# Starting iteration #24
# Building zones with a target population of 6000 individuals
# Built zones in 73.45322 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.523124 seconds (1.0920520666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 24)
# Ran iteration 24 in 223.284173 seconds (3.7214028833333335 minutes)
# Starting iteration #25
# Building zones with a target population of 6000 individuals
# Built zones in 74.057365 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.259094 seconds (1.0876515666666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 25)
# Ran iteration 25 in 222.261843 seconds (3.70436405 minutes)
# Starting iteration #26
# Building zones with a target population of 6000 individuals
# Built zones in 74.90515 seconds.
# Applying zones to point features...
# Assigned income points to zones in 70.89467 seconds (1.1815778333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 26)
# Ran iteration 26 in 223.105465 seconds (3.7184244166666667 minutes)
# Starting iteration #27
# Building zones with a target population of 6000 individuals
# Built zones in 63.0094 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.683115 seconds (0.96138525 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 27)
# Ran iteration 27 in 194.545007 seconds (3.2424167833333333 minutes)
# Starting iteration #28
# Building zones with a target population of 6000 individuals
# Built zones in 66.552401 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.669663 seconds (0.9444943833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 28)
# Ran iteration 28 in 198.093197 seconds (3.3015532833333334 minutes)
# Starting iteration #29
# Building zones with a target population of 6000 individuals
# Built zones in 61.870803 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.229976 seconds (0.9371662666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 29)
# Ran iteration 29 in 191.351937 seconds (3.1891989499999998 minutes)
# Starting iteration #30
# Building zones with a target population of 6000 individuals
# Built zones in 66.39625 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.237942 seconds (0.9372990333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 30)
# Ran iteration 30 in 195.664596 seconds (3.2610766 minutes)
# Starting iteration #31
# Building zones with a target population of 6000 individuals
# Built zones in 69.928443 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.475865 seconds (0.9412644166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 31)
# Ran iteration 31 in 201.100773 seconds (3.35167955 minutes)
# Starting iteration #32
# Building zones with a target population of 6000 individuals
# Built zones in 67.447984 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.23305 seconds (0.9372174999999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 32)
# Ran iteration 32 in 196.907624 seconds (3.281793733333333 minutes)
# Starting iteration #33
# Building zones with a target population of 6000 individuals
# Built zones in 61.802659 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.744649 seconds (0.94574415 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 33)
# Ran iteration 33 in 191.516757 seconds (3.19194595 minutes)
# Starting iteration #34
# Building zones with a target population of 6000 individuals
# Built zones in 71.00519 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.23757 seconds (0.9539595 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 34)
# Ran iteration 34 in 201.825657 seconds (3.36376095 minutes)
# Starting iteration #35
# Building zones with a target population of 6000 individuals
# Built zones in 63.789708 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.990762 seconds (0.9331793666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 35)
# Ran iteration 35 in 192.834746 seconds (3.2139124333333333 minutes)
# Starting iteration #36
# Building zones with a target population of 6000 individuals
# Built zones in 66.322664 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.683017 seconds (0.9280502833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 36)
# Ran iteration 36 in 194.937812 seconds (3.2489635333333333 minutes)
# Starting iteration #37
# Building zones with a target population of 6000 individuals
# Built zones in 61.985238 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.426437 seconds (0.9404406166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 37)
# Ran iteration 37 in 191.330677 seconds (3.1888446166666666 minutes)
# Starting iteration #38
# Building zones with a target population of 6000 individuals
# Built zones in 68.066663 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.506789 seconds (0.9417798166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 38)
# Ran iteration 38 in 197.558322 seconds (3.2926387 minutes)
# Starting iteration #39
# Building zones with a target population of 6000 individuals
# Built zones in 66.723473 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.1081 seconds (0.935135 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 39)
# Ran iteration 39 in 195.854968 seconds (3.264249466666667 minutes)
# Starting iteration #40
# Building zones with a target population of 6000 individuals
# Built zones in 74.517716 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.077301 seconds (0.9846216833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 40)
# Ran iteration 40 in 207.226112 seconds (3.4537685333333332 minutes)
# Starting iteration #41
# Building zones with a target population of 6000 individuals
# Built zones in 62.888977 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.431396 seconds (0.9405232666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 41)
# Ran iteration 41 in 192.464025 seconds (3.20773375 minutes)
# Starting iteration #42
# Building zones with a target population of 6000 individuals
# Built zones in 67.957001 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.192214 seconds (0.9532035666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 42)
# Ran iteration 42 in 198.807333 seconds (3.31345555 minutes)
# Starting iteration #43
# Building zones with a target population of 6000 individuals
# Built zones in 62.194295 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.932972 seconds (0.9322161999999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 43)
# Ran iteration 43 in 192.190865 seconds (3.2031810833333334 minutes)
# Starting iteration #44
# Building zones with a target population of 6000 individuals
# Built zones in 63.764318 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.780326 seconds (0.9463387666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 44)
# Ran iteration 44 in 193.459665 seconds (3.22432775 minutes)
# Starting iteration #45
# Building zones with a target population of 6000 individuals
# Built zones in 67.396822 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.458488 seconds (0.9409748 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 45)
# Ran iteration 45 in 196.938572 seconds (3.282309533333333 minutes)
# Starting iteration #46
# Building zones with a target population of 6000 individuals
# Built zones in 62.130909 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.654802 seconds (0.9442467 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 46)
# Ran iteration 46 in 192.480923 seconds (3.208015383333333 minutes)
# Starting iteration #47
# Building zones with a target population of 6000 individuals
# Built zones in 67.393972 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.858247 seconds (0.9643041166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 47)
# Ran iteration 47 in 198.690001 seconds (3.3115000166666664 minutes)
# Starting iteration #48
# Building zones with a target population of 6000 individuals
# Built zones in 61.725207 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.276539 seconds (0.9379423166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 48)
# Ran iteration 48 in 191.633802 seconds (3.1938967000000003 minutes)
# Starting iteration #49
# Building zones with a target population of 6000 individuals
# Built zones in 62.319252 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.071537 seconds (0.9345256166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 49)
# Ran iteration 49 in 191.682181 seconds (3.194703016666667 minutes)
# Starting iteration #50
# Building zones with a target population of 6000 individuals
# Built zones in 67.836053 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.638635 seconds (0.9606439166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 50)
# Ran iteration 50 in 198.967437 seconds (3.3161239499999997 minutes)
# Starting iteration #51
# Building zones with a target population of 6000 individuals
# Built zones in 61.713895 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.907809 seconds (0.9484634833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 51)
# Ran iteration 51 in 192.424394 seconds (3.2070732333333334 minutes)
# Starting iteration #52
# Building zones with a target population of 6000 individuals
# Built zones in 68.980597 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.260106 seconds (0.9376684333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 52)
# Ran iteration 52 in 198.608699 seconds (3.310144983333333 minutes)
# Starting iteration #53
# Building zones with a target population of 6000 individuals
# Built zones in 61.774405 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.816457 seconds (0.9636076166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 53)
# Ran iteration 53 in 192.624021 seconds (3.21040035 minutes)
# Starting iteration #54
# Building zones with a target population of 6000 individuals
# Built zones in 61.996549 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.812277 seconds (0.9468712833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 54)
# Ran iteration 54 in 192.199091 seconds (3.2033181833333333 minutes)
# Starting iteration #55
# Building zones with a target population of 6000 individuals
# Built zones in 69.181691 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.58639 seconds (0.9431065000000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 55)
# Ran iteration 55 in 199.168796 seconds (3.319479933333333 minutes)
# Starting iteration #56
# Building zones with a target population of 6000 individuals
# Built zones in 61.894965 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.184312 seconds (0.9697385333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 56)
# Ran iteration 56 in 193.593811 seconds (3.2265635166666664 minutes)
# Starting iteration #57
# Building zones with a target population of 6000 individuals
# Built zones in 61.968037 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.132827 seconds (0.9355471166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 57)
# Ran iteration 57 in 192.973293 seconds (3.21622155 minutes)
# Starting iteration #58
# Building zones with a target population of 6000 individuals
# Built zones in 68.847186 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.788747 seconds (0.9464791166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 58)
# Ran iteration 58 in 198.754211 seconds (3.3125701833333334 minutes)
# Starting iteration #59
# Building zones with a target population of 6000 individuals
# Built zones in 62.567561 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.368284 seconds (0.9394714000000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 59)
# Ran iteration 59 in 194.466172 seconds (3.2411028666666666 minutes)
# Starting iteration #60
# Building zones with a target population of 6000 individuals
# Built zones in 61.597276 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.600093 seconds (0.9433348833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 60)
# Ran iteration 60 in 192.18495 seconds (3.2030825 minutes)
# Starting iteration #61
# Building zones with a target population of 6000 individuals
# Built zones in 69.905752 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.295639 seconds (0.93826065 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 61)
# Ran iteration 61 in 199.534298 seconds (3.3255716333333334 minutes)
# Starting iteration #62
# Building zones with a target population of 6000 individuals
# Built zones in 61.581659 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.350915 seconds (0.9391819166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 62)
# Ran iteration 62 in 193.166071 seconds (3.2194345166666665 minutes)
# Starting iteration #63
# Building zones with a target population of 6000 individuals
# Built zones in 62.28603 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.455373 seconds (0.9409228833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 63)
# Ran iteration 63 in 193.4986 seconds (3.224976666666667 minutes)
# Starting iteration #64
# Building zones with a target population of 6000 individuals
# Built zones in 73.283452 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.927958 seconds (0.9321326333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 64)
# Ran iteration 64 in 203.474577 seconds (3.39124295 minutes)
# Starting iteration #65
# Building zones with a target population of 6000 individuals
# Built zones in 62.564237 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.332648 seconds (0.9388774666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 65)
# Ran iteration 65 in 193.751048 seconds (3.2291841333333333 minutes)
# Starting iteration #66
# Building zones with a target population of 6000 individuals
# Built zones in 61.639909 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.511261 seconds (0.94185435 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 66)
# Ran iteration 66 in 192.268011 seconds (3.20446685 minutes)
# Starting iteration #67
# Building zones with a target population of 6000 individuals
# Built zones in 70.316754 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.246924 seconds (0.9374487333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 67)
# Ran iteration 67 in 200.078084 seconds (3.334634733333333 minutes)
# Starting iteration #68
# Building zones with a target population of 6000 individuals
# Built zones in 62.412554 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.953619 seconds (0.9492269833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 68)
# Ran iteration 68 in 193.980301 seconds (3.2330050166666666 minutes)
# Starting iteration #69
# Building zones with a target population of 6000 individuals
# Built zones in 61.640186 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.378327 seconds (0.9396387833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 69)
# Ran iteration 69 in 191.483902 seconds (3.1913983666666668 minutes)
# Starting iteration #70
# Building zones with a target population of 6000 individuals
# Built zones in 61.769515 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.759914 seconds (0.9459985666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 70)
# Ran iteration 70 in 191.957 seconds (3.1992833333333333 minutes)
# Starting iteration #71
# Building zones with a target population of 6000 individuals
# Built zones in 69.696119 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.634688 seconds (0.9439114666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 71)
# Ran iteration 71 in 201.02271 seconds (3.3503784999999997 minutes)
# Starting iteration #72
# Building zones with a target population of 6000 individuals
# Built zones in 62.277977 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.363723 seconds (0.9393953833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 72)
# Ran iteration 72 in 192.723063 seconds (3.21205105 minutes)
# Starting iteration #73
# Building zones with a target population of 6000 individuals
# Built zones in 62.134238 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.016415 seconds (0.9502735833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 73)
# Ran iteration 73 in 192.965028 seconds (3.2160838 minutes)
# Starting iteration #74
# Building zones with a target population of 6000 individuals
# Built zones in 70.253231 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.035081 seconds (0.9505846833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 74)
# Ran iteration 74 in 201.049201 seconds (3.350820016666667 minutes)
# Starting iteration #75
# Building zones with a target population of 6000 individuals
# Built zones in 65.150393 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.49117 seconds (0.9415195 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 75)
# Ran iteration 75 in 195.179287 seconds (3.2529881166666663 minutes)
# Starting iteration #76
# Building zones with a target population of 6000 individuals
# Built zones in 61.977235 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.613388 seconds (0.9435564666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 76)
# Ran iteration 76 in 192.541801 seconds (3.2090300166666665 minutes)
# Starting iteration #77
# Building zones with a target population of 6000 individuals
# Built zones in 62.354314 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.653368 seconds (0.9442228 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 77)
# Ran iteration 77 in 192.872578 seconds (3.214542966666667 minutes)
# Starting iteration #78
# Building zones with a target population of 6000 individuals
# Built zones in 72.907518 seconds.
# Applying zones to point features...
# Assigned income points to zones in 55.841892 seconds (0.9306982 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 78)
# Ran iteration 78 in 205.860753 seconds (3.4310125499999997 minutes)
# Starting iteration #79
# Building zones with a target population of 6000 individuals
# Built zones in 63.259093 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.038668 seconds (0.9673111333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 79)
# Ran iteration 79 in 194.523633 seconds (3.2420605499999997 minutes)
# Starting iteration #80
# Building zones with a target population of 6000 individuals
# Built zones in 62.456112 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.201539 seconds (0.9533589833333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 80)
# Ran iteration 80 in 193.341782 seconds (3.222363033333333 minutes)
# Starting iteration #81
# Building zones with a target population of 6000 individuals
# Built zones in 67.1804 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.183879 seconds (0.95306465 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 81)
# Ran iteration 81 in 197.01466 seconds (3.2835776666666665 minutes)
# Starting iteration #82
# Building zones with a target population of 6000 individuals
# Built zones in 62.880073 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.61848 seconds (1.0936413333333335 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 82)
# Ran iteration 82 in 201.4566 seconds (3.35761 minutes)
# Starting iteration #83
# Building zones with a target population of 6000 individuals
# Built zones in 70.456903 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.581799 seconds (0.9430299833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 83)
# Ran iteration 83 in 201.197108 seconds (3.353285133333333 minutes)
# Starting iteration #84
# Building zones with a target population of 6000 individuals
# Built zones in 73.71033 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.95606 seconds (0.9492676666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 84)
# Ran iteration 84 in 203.473098 seconds (3.3912183 minutes)
# Starting iteration #85
# Building zones with a target population of 6000 individuals
# Built zones in 82.436379 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.83706 seconds (0.9472843333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 85)
# Ran iteration 85 in 213.101425 seconds (3.5516904166666667 minutes)
# Starting iteration #86
# Building zones with a target population of 6000 individuals
# Built zones in 72.694927 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.801092 seconds (0.9466848666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 86)
# Ran iteration 86 in 203.032305 seconds (3.38387175 minutes)
# Starting iteration #87
# Building zones with a target population of 6000 individuals
# Built zones in 73.142738 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.105186 seconds (0.9517531 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 87)
# Ran iteration 87 in 203.5213 seconds (3.3920216666666665 minutes)
# Starting iteration #88
# Building zones with a target population of 6000 individuals
# Built zones in 73.001495 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.709603 seconds (0.94516005 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 88)
# Ran iteration 88 in 203.343416 seconds (3.3890569333333334 minutes)
# Starting iteration #89
# Building zones with a target population of 6000 individuals
# Built zones in 73.547981 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.706798 seconds (0.9451132999999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 89)
# Ran iteration 89 in 206.673627 seconds (3.44456045 minutes)
# Starting iteration #90
# Building zones with a target population of 6000 individuals
# Built zones in 72.55397 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.231862 seconds (0.9538643666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 90)
# Ran iteration 90 in 203.309475 seconds (3.38849125 minutes)
# Starting iteration #91
# Building zones with a target population of 6000 individuals
# Built zones in 73.719477 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.615604 seconds (0.9602600666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 91)
# Ran iteration 91 in 204.763782 seconds (3.4127297 minutes)
# Starting iteration #92
# Building zones with a target population of 6000 individuals
# Built zones in 72.408643 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.755449 seconds (0.9625908166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 92)
# Ran iteration 92 in 204.841583 seconds (3.4140263833333337 minutes)
# Starting iteration #93
# Building zones with a target population of 6000 individuals
# Built zones in 73.218762 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.613963 seconds (0.9602327166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 93)
# Ran iteration 93 in 204.326072 seconds (3.4054345333333336 minutes)
# Starting iteration #94
# Building zones with a target population of 6000 individuals
# Built zones in 83.806519 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.679463 seconds (0.9613243833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 94)
# Ran iteration 94 in 214.898253 seconds (3.5816375500000004 minutes)
# Starting iteration #95
# Building zones with a target population of 6000 individuals
# Built zones in 73.456793 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.81402 seconds (0.9469003333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 95)
# Ran iteration 95 in 208.707334 seconds (3.4784555666666668 minutes)
# Starting iteration #96
# Building zones with a target population of 6000 individuals
# Built zones in 73.875232 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.649326 seconds (0.9608221 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 96)
# Ran iteration 96 in 204.789827 seconds (3.4131637833333333 minutes)
# Starting iteration #97
# Building zones with a target population of 6000 individuals
# Built zones in 73.766325 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.015786 seconds (0.9502631 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 97)
# Ran iteration 97 in 205.052344 seconds (3.417539066666667 minutes)
# Starting iteration #98
# Building zones with a target population of 6000 individuals
# Built zones in 85.105857 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.771311 seconds (0.9461885166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 98)
# Ran iteration 98 in 217.149801 seconds (3.61916335 minutes)
# Starting iteration #99
# Building zones with a target population of 6000 individuals
# Built zones in 74.108531 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.141217 seconds (0.9523536166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 99)
# Ran iteration 99 in 205.151196 seconds (3.4191866 minutes)
# Done with all simulations! Time elapsed: 5:41:08.428211

# %%
Run_Simulation(num_iterations=100, pop_target=2000, zone_characteristic_goal='EQUAL_NUMBER_OF_FEATURES')
# Out:
# Starting simulation with 100 iterations. Zones will be built with population goals of 2000 and zone characteristic EQUAL_NUMBER_OF_FEATURES
# Starting iteration #0
# Building zones with a target population of 2000 individuals
# Built zones in 93.25977 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.131581 seconds (1.0855263499999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 0)
# Ran iteration 0 in 247.427036 seconds (4.123783933333333 minutes)
# Starting iteration #1
# Building zones with a target population of 2000 individuals
# Built zones in 88.668066 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.878219 seconds (1.0979703166666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 1)
# Ran iteration 1 in 240.906527 seconds (4.015108783333334 minutes)
# Starting iteration #2
# Building zones with a target population of 2000 individuals
# Built zones in 87.949164 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.035602 seconds (1.0839267 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 2)
# Ran iteration 2 in 237.768793 seconds (3.9628132166666665 minutes)
# Starting iteration #3
# Building zones with a target population of 2000 individuals
# Built zones in 89.735209 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.697688 seconds (1.0782947999999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 3)
# Ran iteration 3 in 238.272673 seconds (3.9712112166666667 minutes)
# Starting iteration #4
# Building zones with a target population of 2000 individuals
# Built zones in 93.491203 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.305241 seconds (1.10508735 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 4)
# Ran iteration 4 in 243.822023 seconds (4.063700383333333 minutes)
# Starting iteration #5
# Building zones with a target population of 2000 individuals
# Built zones in 90.991305 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.022871 seconds (1.06704785 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 5)
# Ran iteration 5 in 239.071281 seconds (3.98452135 minutes)
# Starting iteration #6
# Building zones with a target population of 2000 individuals
# Built zones in 85.617993 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.334813 seconds (1.0722468833333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 6)
# Ran iteration 6 in 238.584759 seconds (3.97641265 minutes)
# Starting iteration #7
# Building zones with a target population of 2000 individuals
# Built zones in 89.969514 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.04715 seconds (1.0507858333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 7)
# Ran iteration 7 in 236.675244 seconds (3.9445874 minutes)
# Starting iteration #8
# Building zones with a target population of 2000 individuals
# Built zones in 91.520594 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.516648 seconds (1.0752774666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 8)
# Ran iteration 8 in 240.072986 seconds (4.001216433333333 minutes)
# Starting iteration #9
# Building zones with a target population of 2000 individuals
# Built zones in 92.804133 seconds.
# Applying zones to point features...
# Assigned income points to zones in 67.101477 seconds (1.11835795 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 9)
# Ran iteration 9 in 245.363631 seconds (4.0893938499999996 minutes)
# Starting iteration #10
# Building zones with a target population of 2000 individuals
# Built zones in 94.150652 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.616638 seconds (1.0769439666666665 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 10)
# Ran iteration 10 in 244.018961 seconds (4.066982683333333 minutes)
# Starting iteration #11
# Building zones with a target population of 2000 individuals
# Built zones in 93.621268 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.111982 seconds (1.0851997 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 11)
# Ran iteration 11 in 245.403501 seconds (4.0900583500000005 minutes)
# Starting iteration #12
# Building zones with a target population of 2000 individuals
# Built zones in 109.282009 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.248803 seconds (1.1041467166666665 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 12)
# Ran iteration 12 in 259.219016 seconds (4.320316933333333 minutes)
# Starting iteration #13
# Building zones with a target population of 2000 individuals
# Built zones in 99.405373 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.456612 seconds (1.0909435333333335 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 13)
# Ran iteration 13 in 247.799914 seconds (4.129998566666667 minutes)
# Starting iteration #14
# Building zones with a target population of 2000 individuals
# Built zones in 112.298926 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.514833 seconds (1.0919138833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 14)
# Ran iteration 14 in 260.769646 seconds (4.346160766666667 minutes)
# Starting iteration #15
# Building zones with a target population of 2000 individuals
# Built zones in 101.165033 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.458868 seconds (1.0909811333333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 15)
# Ran iteration 15 in 252.686621 seconds (4.211443683333333 minutes)
# Starting iteration #16
# Building zones with a target population of 2000 individuals
# Built zones in 101.903683 seconds.
# Applying zones to point features...
# Assigned income points to zones in 67.198357 seconds (1.1199726166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 16)
# Ran iteration 16 in 255.035073 seconds (4.25058455 minutes)
# Starting iteration #17
# Building zones with a target population of 2000 individuals
# Built zones in 101.391674 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.331926 seconds (1.1055321 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 17)
# Ran iteration 17 in 250.857674 seconds (4.180961233333333 minutes)
# Starting iteration #18
# Building zones with a target population of 2000 individuals
# Built zones in 102.017489 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.680628 seconds (1.0780104666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 18)
# Ran iteration 18 in 253.12058 seconds (4.218676333333333 minutes)
# Starting iteration #19
# Building zones with a target population of 2000 individuals
# Built zones in 116.313231 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.469605 seconds (1.0911600833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 19)
# Ran iteration 19 in 266.259094 seconds (4.437651566666667 minutes)
# Starting iteration #20
# Building zones with a target population of 2000 individuals
# Built zones in 125.621485 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.377448 seconds (1.0729574666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 20)
# Ran iteration 20 in 272.695594 seconds (4.544926566666667 minutes)
# Starting iteration #21
# Building zones with a target population of 2000 individuals
# Built zones in 128.710191 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.55969 seconds (1.0759948333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 21)
# Ran iteration 21 in 277.894436 seconds (4.631573933333333 minutes)
# Starting iteration #22
# Building zones with a target population of 2000 individuals
# Built zones in 128.876778 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.873976 seconds (1.0812329333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 22)
# Ran iteration 22 in 279.240982 seconds (4.654016366666666 minutes)
# Starting iteration #23
# Building zones with a target population of 2000 individuals
# Built zones in 107.384946 seconds.
# Applying zones to point features...
# Assigned income points to zones in 67.833227 seconds (1.1305537833333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 23)
# Ran iteration 23 in 259.688849 seconds (4.328147483333334 minutes)
# Starting iteration #24
# Building zones with a target population of 2000 individuals
# Built zones in 108.562281 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.140138 seconds (1.0690023 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 24)
# Ran iteration 24 in 259.296458 seconds (4.321607633333333 minutes)
# Starting iteration #25
# Building zones with a target population of 2000 individuals
# Built zones in 109.610732 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.419717 seconds (1.0736619500000002 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 25)
# Ran iteration 25 in 258.948654 seconds (4.3158109 minutes)
# Starting iteration #26
# Building zones with a target population of 2000 individuals
# Built zones in 145.375267 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.287694 seconds (1.0881282333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 26)
# Ran iteration 26 in 303.184209 seconds (5.05307015 minutes)
# Starting iteration #27
# Building zones with a target population of 2000 individuals
# Built zones in 113.158876 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.47929 seconds (1.0913215 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 27)
# Ran iteration 27 in 267.422516 seconds (4.457041933333333 minutes)
# Starting iteration #28
# Building zones with a target population of 2000 individuals
# Built zones in 113.79558 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.329743 seconds (1.1054957166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 28)
# Ran iteration 28 in 263.990165 seconds (4.399836083333333 minutes)
# Starting iteration #29
# Building zones with a target population of 2000 individuals
# Built zones in 131.961825 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.031688 seconds (1.1005281333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 29)
# Ran iteration 29 in 281.59293 seconds (4.6932155 minutes)
# Starting iteration #30
# Building zones with a target population of 2000 individuals
# Built zones in 147.603383 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.309683 seconds (1.0884947166666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 30)
# Ran iteration 30 in 299.696819 seconds (4.9949469833333335 minutes)
# Starting iteration #31
# Building zones with a target population of 2000 individuals
# Built zones in 114.797458 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.268007 seconds (1.0544667833333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 31)
# Ran iteration 31 in 259.839158 seconds (4.330652633333333 minutes)
# Starting iteration #32
# Building zones with a target population of 2000 individuals
# Built zones in 159.866124 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.26729 seconds (1.0877881666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 32)
# Ran iteration 32 in 313.231661 seconds (5.220527683333333 minutes)
# Starting iteration #33
# Building zones with a target population of 2000 individuals
# Built zones in 115.165293 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.379287 seconds (1.0729881166666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 33)
# Ran iteration 33 in 266.343883 seconds (4.439064716666667 minutes)
# Starting iteration #34
# Building zones with a target population of 2000 individuals
# Built zones in 117.945694 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.592558 seconds (1.0598759666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 34)
# Ran iteration 34 in 269.194948 seconds (4.4865824666666665 minutes)
# Starting iteration #35
# Building zones with a target population of 2000 individuals
# Built zones in 119.167797 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.240591 seconds (1.0540098500000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 35)
# Ran iteration 35 in 264.965684 seconds (4.416094733333334 minutes)
# Starting iteration #36
# Building zones with a target population of 2000 individuals
# Built zones in 160.362985 seconds.
# Applying zones to point features...
# Assigned income points to zones in 67.743479 seconds (1.1290579833333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 36)
# Ran iteration 36 in 312.781756 seconds (5.213029266666666 minutes)
# Starting iteration #37
# Building zones with a target population of 2000 individuals
# Built zones in 119.252728 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.122184 seconds (1.0687030666666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 37)
# Ran iteration 37 in 270.48107 seconds (4.508017833333333 minutes)
# Starting iteration #38
# Building zones with a target population of 2000 individuals
# Built zones in 121.240285 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.03541 seconds (1.1005901666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 38)
# Ran iteration 38 in 270.957236 seconds (4.515953933333334 minutes)
# Starting iteration #39
# Building zones with a target population of 2000 individuals
# Built zones in 163.102066 seconds.
# Applying zones to point features...
# Assigned income points to zones in 70.704926 seconds (1.1784154333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 39)
# Ran iteration 39 in 318.518075 seconds (5.308634583333333 minutes)
# Starting iteration #40
# Building zones with a target population of 2000 individuals
# Built zones in 125.005298 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.826514 seconds (1.1137752333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 40)
# Ran iteration 40 in 279.653381 seconds (4.660889683333334 minutes)
# Starting iteration #41
# Building zones with a target population of 2000 individuals
# Built zones in 124.637068 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.843158 seconds (1.0807193 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 41)
# Ran iteration 41 in 277.215606 seconds (4.620260099999999 minutes)
# Starting iteration #42
# Building zones with a target population of 2000 individuals
# Built zones in 132.672572 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.87001 seconds (1.0645001666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 42)
# Ran iteration 42 in 280.546239 seconds (4.6757706500000005 minutes)
# Starting iteration #43
# Building zones with a target population of 2000 individuals
# Built zones in 163.202442 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.165022 seconds (1.0860836999999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 43)
# Ran iteration 43 in 314.497456 seconds (5.241624266666666 minutes)
# Starting iteration #44
# Building zones with a target population of 2000 individuals
# Built zones in 128.626818 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.824798 seconds (1.0804133 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 44)
# Ran iteration 44 in 282.597696 seconds (4.7099616 minutes)
# Starting iteration #45
# Building zones with a target population of 2000 individuals
# Built zones in 139.632319 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.845796 seconds (1.0807632666666669 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 45)
# Ran iteration 45 in 287.890289 seconds (4.798171483333333 minutes)
# Starting iteration #46
# Building zones with a target population of 2000 individuals
# Built zones in 178.657668 seconds.
# Applying zones to point features...
# Assigned income points to zones in 67.872642 seconds (1.1312107 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 46)
# Ran iteration 46 in 333.17859 seconds (5.5529765 minutes)
# Starting iteration #47
# Building zones with a target population of 2000 individuals
# Built zones in 132.307398 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.366029 seconds (1.07276715 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 47)
# Ran iteration 47 in 285.223151 seconds (4.753719183333333 minutes)
# Starting iteration #48
# Building zones with a target population of 2000 individuals
# Built zones in 149.648277 seconds.
# Applying zones to point features...
# Assigned income points to zones in 128.781549 seconds (2.1463591500000003 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 48)
# Ran iteration 48 in 467.2949 seconds (7.788248333333333 minutes)
# Starting iteration #49
# Building zones with a target population of 2000 individuals
# Built zones in 138.43754 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.593463 seconds (1.10989105 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 49)
# Ran iteration 49 in 291.527683 seconds (4.858794716666667 minutes)
# Starting iteration #50
# Building zones with a target population of 2000 individuals
# Built zones in 135.697359 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.733689 seconds (1.11222815 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 50)
# Ran iteration 50 in 287.979692 seconds (4.7996615333333335 minutes)
# Starting iteration #51
# Building zones with a target population of 2000 individuals
# Built zones in 142.647255 seconds.
# Applying zones to point features...
# Assigned income points to zones in 78.215298 seconds (1.3035883000000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 51)
# Ran iteration 51 in 339.921985 seconds (5.665366416666667 minutes)
# Starting iteration #52
# Building zones with a target population of 2000 individuals
# Built zones in 140.674275 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.18876 seconds (1.0864793333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 52)
# Ran iteration 52 in 294.497089 seconds (4.908284816666667 minutes)
# Starting iteration #53
# Building zones with a target population of 2000 individuals
# Built zones in 169.795639 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.037146 seconds (1.0839524333333335 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 53)
# Ran iteration 53 in 322.315525 seconds (5.371925416666667 minutes)
# Starting iteration #54
# Building zones with a target population of 2000 individuals
# Built zones in 170.174119 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.265004 seconds (1.0877500666666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 54)
# Ran iteration 54 in 322.517889 seconds (5.375298150000001 minutes)
# Starting iteration #55
# Building zones with a target population of 2000 individuals
# Built zones in 172.78497 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.248499 seconds (1.0874749833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 55)
# Ran iteration 55 in 324.057544 seconds (5.400959066666667 minutes)
# Starting iteration #56
# Building zones with a target population of 2000 individuals
# Built zones in 198.642315 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.104489 seconds (1.0850748166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 56)
# Ran iteration 56 in 347.679361 seconds (5.794656016666666 minutes)
# Starting iteration #57
# Building zones with a target population of 2000 individuals
# Built zones in 190.178781 seconds.
# Applying zones to point features...
# Assigned income points to zones in 67.587786 seconds (1.1264630999999998 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 57)
# Ran iteration 57 in 345.247905 seconds (5.75413175 minutes)
# Starting iteration #58
# Building zones with a target population of 2000 individuals
# Built zones in 143.83535 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.992238 seconds (1.0832039666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 58)
# Ran iteration 58 in 296.210129 seconds (4.936835483333334 minutes)
# Starting iteration #59
# Building zones with a target population of 2000 individuals
# Built zones in 183.989843 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.063619 seconds (1.0677269833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 59)
# Ran iteration 59 in 334.010789 seconds (5.566846483333333 minutes)
# Starting iteration #60
# Building zones with a target population of 2000 individuals
# Built zones in 186.209947 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.0239 seconds (1.067065 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 60)
# Ran iteration 60 in 337.834585 seconds (5.630576416666667 minutes)
# Starting iteration #61
# Building zones with a target population of 2000 individuals
# Built zones in 190.298084 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.206236 seconds (1.0867706000000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 61)
# Ran iteration 61 in 339.621138 seconds (5.6603523 minutes)
# Starting iteration #62
# Building zones with a target population of 2000 individuals
# Built zones in 216.061919 seconds.
# Applying zones to point features...
# Assigned income points to zones in 68.019099 seconds (1.13365165 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 62)
# Ran iteration 62 in 372.474279 seconds (6.207904650000001 minutes)
# Starting iteration #63
# Building zones with a target population of 2000 individuals
# Built zones in 150.086625 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.687625 seconds (1.09479375 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 63)
# Ran iteration 63 in 314.237519 seconds (5.237291983333334 minutes)
# Starting iteration #64
# Building zones with a target population of 2000 individuals
# Built zones in 203.009339 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.503359 seconds (1.0083893166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 64)
# Ran iteration 64 in 339.827585 seconds (5.663793083333333 minutes)
# Starting iteration #65
# Building zones with a target population of 2000 individuals
# Built zones in 192.278946 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.313358 seconds (0.9885559666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 65)
# Ran iteration 65 in 328.264111 seconds (5.471068516666667 minutes)
# Starting iteration #66
# Building zones with a target population of 2000 individuals
# Built zones in 145.144302 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.609341 seconds (0.9434890166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 66)
# Ran iteration 66 in 278.182481 seconds (4.636374683333333 minutes)
# Starting iteration #67
# Building zones with a target population of 2000 individuals
# Built zones in 206.793004 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.449497 seconds (1.04082495 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 67)
# Ran iteration 67 in 347.220442 seconds (5.787007366666667 minutes)
# Starting iteration #68
# Building zones with a target population of 2000 individuals
# Built zones in 209.90502 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.638661 seconds (1.0439776833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 68)
# Ran iteration 68 in 350.199505 seconds (5.836658416666666 minutes)
# Starting iteration #69
# Building zones with a target population of 2000 individuals
# Built zones in 142.591103 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.929419 seconds (1.1154903166666665 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 69)
# Ran iteration 69 in 297.702235 seconds (4.961703916666666 minutes)
# Starting iteration #70
# Building zones with a target population of 2000 individuals
# Built zones in 144.102622 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.469218 seconds (1.0578203 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 70)
# Ran iteration 70 in 283.047096 seconds (4.7174516 minutes)
# Starting iteration #71
# Building zones with a target population of 2000 individuals
# Built zones in 143.011377 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.45621 seconds (1.0242701666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 71)
# Ran iteration 71 in 283.187965 seconds (4.719799416666667 minutes)
# Starting iteration #72
# Building zones with a target population of 2000 individuals
# Built zones in 149.655681 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.24934 seconds (1.1041556666666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 72)
# Ran iteration 72 in 307.595924 seconds (5.126598733333334 minutes)
# Starting iteration #73
# Building zones with a target population of 2000 individuals
# Built zones in 149.735556 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.501539 seconds (1.0083589833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 73)
# Ran iteration 73 in 295.659614 seconds (4.927660233333333 minutes)
# Starting iteration #74
# Building zones with a target population of 2000 individuals
# Built zones in 213.4526 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.238275 seconds (1.00397125 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 74)
# Ran iteration 74 in 350.690275 seconds (5.844837916666666 minutes)
# Starting iteration #75
# Building zones with a target population of 2000 individuals
# Built zones in 205.495893 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.420155 seconds (0.97366925 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 75)
# Ran iteration 75 in 338.694072 seconds (5.6449012000000005 minutes)
# Starting iteration #76
# Building zones with a target population of 2000 individuals
# Built zones in 159.560779 seconds.
# Applying zones to point features...
# Assigned income points to zones in 56.001921 seconds (0.9333653500000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 76)
# Ran iteration 76 in 287.842148 seconds (4.7973691333333335 minutes)
# Starting iteration #77
# Building zones with a target population of 2000 individuals
# Built zones in 218.391402 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.791291 seconds (0.9631881833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 77)
# Ran iteration 77 in 351.730719 seconds (5.862178650000001 minutes)
# Starting iteration #78
# Building zones with a target population of 2000 individuals
# Built zones in 222.468727 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.066286 seconds (1.0177714333333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 78)
# Ran iteration 78 in 362.609342 seconds (6.0434890333333335 minutes)
# Starting iteration #79
# Building zones with a target population of 2000 individuals
# Built zones in 259.40297 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.190831 seconds (1.0198471833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 79)
# Ran iteration 79 in 413.237457 seconds (6.88729095 minutes)
# Starting iteration #80
# Building zones with a target population of 2000 individuals
# Built zones in 196.095723 seconds.
# Applying zones to point features...
# Assigned income points to zones in 82.387459 seconds (1.3731243166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 80)
# Ran iteration 80 in 397.163467 seconds (6.619391116666667 minutes)
# Starting iteration #81
# Building zones with a target population of 2000 individuals
# Built zones in 360.366196 seconds.
# Applying zones to point features...
# Assigned income points to zones in 73.258097 seconds (1.2209682833333335 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 81)
# Ran iteration 81 in 540.324862 seconds (9.005414366666667 minutes)
# Starting iteration #82
# Building zones with a target population of 2000 individuals
# Built zones in 178.2609 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.312019 seconds (1.0718669833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 82)
# Ran iteration 82 in 336.726724 seconds (5.612112066666667 minutes)
# Starting iteration #83
# Building zones with a target population of 2000 individuals
# Built zones in 286.705625 seconds.
# Applying zones to point features...
# Assigned income points to zones in 73.965 seconds (1.23275 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 83)
# Ran iteration 83 in 466.203504 seconds (7.7700584 minutes)
# Starting iteration #84
# Building zones with a target population of 2000 individuals
# Built zones in 214.035632 seconds.
# Applying zones to point features...
# Assigned income points to zones in 68.028081 seconds (1.13380135 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 84)
# Ran iteration 84 in 374.566192 seconds (6.2427698666666664 minutes)
# Starting iteration #85
# Building zones with a target population of 2000 individuals
# Built zones in 315.698695 seconds.
# Applying zones to point features...
# Assigned income points to zones in 76.869409 seconds (1.2811568166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 85)
# Ran iteration 85 in 506.975039 seconds (8.449583983333333 minutes)
# Starting iteration #86
# Building zones with a target population of 2000 individuals
# Built zones in 220.733275 seconds.
# Applying zones to point features...
# Assigned income points to zones in 70.629085 seconds (1.1771514166666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 86)
# Ran iteration 86 in 403.006805 seconds (6.716780083333333 minutes)
# Starting iteration #87
# Building zones with a target population of 2000 individuals
# Built zones in 307.536084 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.134152 seconds (1.1022358666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 87)
# Ran iteration 87 in 465.434362 seconds (7.757239366666667 minutes)
# Starting iteration #88
# Building zones with a target population of 2000 individuals
# Built zones in 401.452698 seconds.
# Applying zones to point features...
# Assigned income points to zones in 72.327583 seconds (1.2054597166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 88)
# Ran iteration 88 in 571.473992 seconds (9.524566533333333 minutes)
# Starting iteration #89
# Building zones with a target population of 2000 individuals
# Built zones in 176.298127 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.441672 seconds (1.0740278666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 89)
# Ran iteration 89 in 343.144949 seconds (5.719082483333334 minutes)
# Starting iteration #90
# Building zones with a target population of 2000 individuals
# Built zones in 274.098015 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.244873 seconds (1.0540812166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 90)
# Ran iteration 90 in 433.210521 seconds (7.220175350000001 minutes)
# Starting iteration #91
# Building zones with a target population of 2000 individuals
# Built zones in 282.164443 seconds.
# Applying zones to point features...
# Assigned income points to zones in 74.971512 seconds (1.2495252000000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 91)
# Ran iteration 91 in 464.33429 seconds (7.738904833333334 minutes)
# Starting iteration #92
# Building zones with a target population of 2000 individuals
# Built zones in 230.982314 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.561026 seconds (1.0593504333333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 92)
# Ran iteration 92 in 382.763426 seconds (6.379390433333333 minutes)
# Starting iteration #93
# Building zones with a target population of 2000 individuals
# Built zones in 318.616964 seconds.
# Applying zones to point features...
# Assigned income points to zones in 70.08939 seconds (1.1681564999999998 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 93)
# Ran iteration 93 in 488.308479 seconds (8.13847465 minutes)
# Starting iteration #94
# Building zones with a target population of 2000 individuals
# Built zones in 274.623623 seconds.
# Applying zones to point features...
# Assigned income points to zones in 76.005748 seconds (1.2667624666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 94)
# Ran iteration 94 in 457.305086 seconds (7.621751433333333 minutes)
# Starting iteration #95
# Building zones with a target population of 2000 individuals
# Built zones in 239.407782 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.764483 seconds (1.0627413833333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 95)
# Ran iteration 95 in 411.378902 seconds (6.856315033333333 minutes)
# Starting iteration #96
# Building zones with a target population of 2000 individuals
# Built zones in 290.190978 seconds.
# Applying zones to point features...
# Assigned income points to zones in 76.076558 seconds (1.2679426333333335 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 96)
# Ran iteration 96 in 471.855178 seconds (7.864252966666667 minutes)
# Starting iteration #97
# Building zones with a target population of 2000 individuals
# Built zones in 247.883118 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.647794 seconds (1.0607965666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 97)
# Ran iteration 97 in 418.134836 seconds (6.968913933333334 minutes)
# Starting iteration #98
# Building zones with a target population of 2000 individuals
# Built zones in 285.843605 seconds.
# Applying zones to point features...
# Assigned income points to zones in 77.00009 seconds (1.2833348333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 98)
# Ran iteration 98 in 467.57662 seconds (7.792943666666667 minutes)
# Starting iteration #99
# Building zones with a target population of 2000 individuals
# Built zones in 253.682609 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.140813 seconds (1.06901355 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 99)
# Ran iteration 99 in 424.749483 seconds (7.07915805 minutes)
# Done with all simulations! Time elapsed: 8:57:11.725883

# %%
Run_Simulation(num_iterations=100, pop_target=4000, zone_characteristic_goal='EQUAL_NUMBER_OF_FEATURES')
# Out:
# Starting simulation with 100 iterations. Zones will be built with population goals of 4000 and zone characteristic EQUAL_NUMBER_OF_FEATURES
# Starting iteration #0
# Building zones with a target population of 4000 individuals
# Built zones in 83.664848 seconds.
# Applying zones to point features...
# Assigned income points to zones in 73.373952 seconds (1.2228992 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 0)
# Ran iteration 0 in 249.272864 seconds (4.154547733333334 minutes)
# Starting iteration #1
# Building zones with a target population of 4000 individuals
# Built zones in 78.020356 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.40347 seconds (1.0067245 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 1)
# Ran iteration 1 in 219.472094 seconds (3.657868233333333 minutes)
# Starting iteration #2
# Building zones with a target population of 4000 individuals
# Built zones in 69.253323 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.358265 seconds (0.9893044166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 2)
# Ran iteration 2 in 210.119621 seconds (3.501993683333333 minutes)
# Starting iteration #3
# Building zones with a target population of 4000 individuals
# Built zones in 70.01477 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.2705 seconds (0.9878416666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 3)
# Ran iteration 3 in 211.051613 seconds (3.5175268833333333 minutes)
# Starting iteration #4
# Building zones with a target population of 4000 individuals
# Built zones in 68.364182 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.705336 seconds (0.9950889333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 4)
# Ran iteration 4 in 218.948495 seconds (3.6491415833333334 minutes)
# Starting iteration #5
# Building zones with a target population of 4000 individuals
# Built zones in 68.282401 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.483257 seconds (1.0080542833333335 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 5)
# Ran iteration 5 in 208.899366 seconds (3.4816561 minutes)
# Starting iteration #6
# Building zones with a target population of 4000 individuals
# Built zones in 68.041045 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.916424 seconds (1.0319404 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 6)
# Ran iteration 6 in 210.907997 seconds (3.5151332833333333 minutes)
# Starting iteration #7
# Building zones with a target population of 4000 individuals
# Built zones in 70.647078 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.902159 seconds (0.9650359833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 7)
# Ran iteration 7 in 209.250427 seconds (3.487507116666667 minutes)
# Starting iteration #8
# Building zones with a target population of 4000 individuals
# Built zones in 72.957898 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.605603 seconds (0.9934267166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 8)
# Ran iteration 8 in 212.956516 seconds (3.5492752666666667 minutes)
# Starting iteration #9
# Building zones with a target population of 4000 individuals
# Built zones in 67.571303 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.81073 seconds (0.9801788333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 9)
# Ran iteration 9 in 206.7182 seconds (3.4453033333333334 minutes)
# Starting iteration #10
# Building zones with a target population of 4000 individuals
# Built zones in 69.168033 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.437056 seconds (0.9906176 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 10)
# Ran iteration 10 in 208.874434 seconds (3.4812405666666666 minutes)
# Starting iteration #11
# Building zones with a target population of 4000 individuals
# Built zones in 68.332269 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.946692 seconds (0.9991115333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 11)
# Ran iteration 11 in 208.751762 seconds (3.4791960333333334 minutes)
# Starting iteration #12
# Building zones with a target population of 4000 individuals
# Built zones in 69.206928 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.416109 seconds (0.9902684833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 12)
# Ran iteration 12 in 209.390054 seconds (3.489834233333333 minutes)
# Starting iteration #13
# Building zones with a target population of 4000 individuals
# Built zones in 71.887761 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.897498 seconds (0.9816249666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 13)
# Ran iteration 13 in 211.004737 seconds (3.516745616666667 minutes)
# Starting iteration #14
# Building zones with a target population of 4000 individuals
# Built zones in 76.498431 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.027823 seconds (0.9671303833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 14)
# Ran iteration 14 in 213.705514 seconds (3.5617585666666667 minutes)
# Starting iteration #15
# Building zones with a target population of 4000 individuals
# Built zones in 68.655405 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.307076 seconds (0.9717846 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 15)
# Ran iteration 15 in 209.593511 seconds (3.4932251833333336 minutes)
# Starting iteration #16
# Building zones with a target population of 4000 individuals
# Built zones in 67.672035 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.023486 seconds (1.0003914333333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 16)
# Ran iteration 16 in 209.576557 seconds (3.492942616666667 minutes)
# Starting iteration #17
# Building zones with a target population of 4000 individuals
# Built zones in 67.663056 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.54843 seconds (0.9758071666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 17)
# Ran iteration 17 in 208.546311 seconds (3.47577185 minutes)
# Starting iteration #18
# Building zones with a target population of 4000 individuals
# Built zones in 68.707265 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.738249 seconds (0.9956374833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 18)
# Ran iteration 18 in 210.566907 seconds (3.50944845 minutes)
# Starting iteration #19
# Building zones with a target population of 4000 individuals
# Built zones in 66.945976 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.436706 seconds (1.0239451 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 19)
# Ran iteration 19 in 209.26439 seconds (3.4877398333333334 minutes)
# Starting iteration #20
# Building zones with a target population of 4000 individuals
# Built zones in 68.856865 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.931083 seconds (0.96551805 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 20)
# Ran iteration 20 in 209.426957 seconds (3.490449283333333 minutes)
# Starting iteration #21
# Building zones with a target population of 4000 individuals
# Built zones in 66.804363 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.484602 seconds (0.9747433666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 21)
# Ran iteration 21 in 208.005755 seconds (3.4667625833333333 minutes)
# Starting iteration #22
# Building zones with a target population of 4000 individuals
# Built zones in 67.148433 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.585332 seconds (0.9764222 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 22)
# Ran iteration 22 in 209.074899 seconds (3.48458165 minutes)
# Starting iteration #23
# Building zones with a target population of 4000 individuals
# Built zones in 66.9739 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.647168 seconds (0.9774528 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 23)
# Ran iteration 23 in 211.733787 seconds (3.52889645 minutes)
# Starting iteration #24
# Building zones with a target population of 4000 individuals
# Built zones in 68.863845 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.254218 seconds (0.9709036333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 24)
# Ran iteration 24 in 210.24477 seconds (3.5040795 minutes)
# Starting iteration #25
# Building zones with a target population of 4000 individuals
# Built zones in 66.811334 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.786121 seconds (0.99643535 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 25)
# Ran iteration 25 in 209.901687 seconds (3.49836145 minutes)
# Starting iteration #26
# Building zones with a target population of 4000 individuals
# Built zones in 66.622839 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.592639 seconds (0.99321065 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 26)
# Ran iteration 26 in 208.49744 seconds (3.4749573333333337 minutes)
# Starting iteration #27
# Building zones with a target population of 4000 individuals
# Built zones in 66.418387 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.233273 seconds (0.9705545499999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 27)
# Ran iteration 27 in 208.036674 seconds (3.4672779 minutes)
# Starting iteration #28
# Building zones with a target population of 4000 individuals
# Built zones in 67.292051 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.089983 seconds (0.98483305 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 28)
# Ran iteration 28 in 208.735804 seconds (3.4789300666666665 minutes)
# Starting iteration #29
# Building zones with a target population of 4000 individuals
# Built zones in 66.966923 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.735253 seconds (0.99558755 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 29)
# Ran iteration 29 in 207.233821 seconds (3.4538970166666667 minutes)
# Starting iteration #30
# Building zones with a target population of 4000 individuals
# Built zones in 69.693627 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.849293 seconds (1.0141548833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 30)
# Ran iteration 30 in 211.21717 seconds (3.5202861666666667 minutes)
# Starting iteration #31
# Building zones with a target population of 4000 individuals
# Built zones in 67.688001 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.051736 seconds (1.0175289333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 31)
# Ran iteration 31 in 209.367117 seconds (3.4894519500000003 minutes)
# Starting iteration #32
# Building zones with a target population of 4000 individuals
# Built zones in 67.733868 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.255518 seconds (1.0375919666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 32)
# Ran iteration 32 in 210.215845 seconds (3.5035974166666666 minutes)
# Starting iteration #33
# Building zones with a target population of 4000 individuals
# Built zones in 68.060994 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.702011 seconds (1.02836685 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 33)
# Ran iteration 33 in 209.656343 seconds (3.494272383333333 minutes)
# Starting iteration #34
# Building zones with a target population of 4000 individuals
# Built zones in 67.186332 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.567337 seconds (1.0761222833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 34)
# Ran iteration 34 in 212.183585 seconds (3.536393083333333 minutes)
# Starting iteration #35
# Building zones with a target population of 4000 individuals
# Built zones in 67.802684 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.453987 seconds (1.0408997833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 35)
# Ran iteration 35 in 209.992444 seconds (3.4998740666666666 minutes)
# Starting iteration #36
# Building zones with a target population of 4000 individuals
# Built zones in 68.68732 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.132847 seconds (1.03554745 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 36)
# Ran iteration 36 in 213.249734 seconds (3.5541622333333334 minutes)
# Starting iteration #37
# Building zones with a target population of 4000 individuals
# Built zones in 68.774087 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.043087 seconds (1.03405145 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 37)
# Ran iteration 37 in 212.121749 seconds (3.535362483333333 minutes)
# Starting iteration #38
# Building zones with a target population of 4000 individuals
# Built zones in 66.471245 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.656122 seconds (1.0276020333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 38)
# Ran iteration 38 in 208.102498 seconds (3.4683749666666666 minutes)
# Starting iteration #39
# Building zones with a target population of 4000 individuals
# Built zones in 66.565991 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.883513 seconds (1.0313918833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 39)
# Ran iteration 39 in 209.544641 seconds (3.4924106833333335 minutes)
# Starting iteration #40
# Building zones with a target population of 4000 individuals
# Built zones in 66.869181 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.828661 seconds (1.0304776833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 40)
# Ran iteration 40 in 210.844167 seconds (3.51406945 minutes)
# Starting iteration #41
# Building zones with a target population of 4000 individuals
# Built zones in 67.161399 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.209966 seconds (1.0534994333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 41)
# Ran iteration 41 in 210.823223 seconds (3.5137203833333337 minutes)
# Starting iteration #42
# Building zones with a target population of 4000 individuals
# Built zones in 66.622839 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.234574 seconds (1.0372429 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 42)
# Ran iteration 42 in 210.038321 seconds (3.5006386833333334 minutes)
# Starting iteration #43
# Building zones with a target population of 4000 individuals
# Built zones in 66.860205 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.86788 seconds (1.047798 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 43)
# Ran iteration 43 in 210.199889 seconds (3.5033314833333336 minutes)
# Starting iteration #44
# Building zones with a target population of 4000 individuals
# Built zones in 66.435339 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.662128 seconds (0.9777021333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 44)
# Ran iteration 44 in 210.668644 seconds (3.5111440666666667 minutes)
# Starting iteration #45
# Building zones with a target population of 4000 individuals
# Built zones in 66.990856 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.626873 seconds (1.0104478833333335 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 45)
# Ran iteration 45 in 212.42493 seconds (3.5404155 minutes)
# Starting iteration #46
# Building zones with a target population of 4000 individuals
# Built zones in 66.682679 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.600943 seconds (1.0100157166666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 46)
# Ran iteration 46 in 212.605456 seconds (3.543424266666667 minutes)
# Starting iteration #47
# Building zones with a target population of 4000 individuals
# Built zones in 70.000805 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.010196 seconds (0.9835032666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 47)
# Ran iteration 47 in 214.855453 seconds (3.580924216666667 minutes)
# Starting iteration #48
# Building zones with a target population of 4000 individuals
# Built zones in 68.644435 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.514179 seconds (1.0085696499999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 48)
# Ran iteration 48 in 214.830507 seconds (3.5805084500000004 minutes)
# Starting iteration #49
# Building zones with a target population of 4000 individuals
# Built zones in 67.081614 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.893508 seconds (0.9815584666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 49)
# Ran iteration 49 in 211.701873 seconds (3.52836455 minutes)
# Starting iteration #50
# Building zones with a target population of 4000 individuals
# Built zones in 67.314989 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.406811 seconds (0.97344685 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 50)
# Ran iteration 50 in 211.013713 seconds (3.5168952166666667 minutes)
# Starting iteration #51
# Building zones with a target population of 4000 individuals
# Built zones in 67.520438 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.72795 seconds (0.9787991666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 51)
# Ran iteration 51 in 212.890695 seconds (3.54817825 minutes)
# Starting iteration #52
# Building zones with a target population of 4000 individuals
# Built zones in 69.37448 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.017503 seconds (1.0002917166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 52)
# Ran iteration 52 in 216.087145 seconds (3.6014524166666666 minutes)
# Starting iteration #53
# Building zones with a target population of 4000 individuals
# Built zones in 66.748505 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.645182 seconds (0.9774197 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 53)
# Ran iteration 53 in 213.467153 seconds (3.557785883333333 minutes)
# Starting iteration #54
# Building zones with a target population of 4000 individuals
# Built zones in 69.85719 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.598297 seconds (0.9766382833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 54)
# Ran iteration 54 in 214.596134 seconds (3.5766022333333334 minutes)
# Starting iteration #55
# Building zones with a target population of 4000 individuals
# Built zones in 66.686668 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.431744 seconds (0.9738624 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 55)
# Ran iteration 55 in 211.203206 seconds (3.520053433333333 minutes)
# Starting iteration #56
# Building zones with a target population of 4000 individuals
# Built zones in 66.981879 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.343979 seconds (0.97239965 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 56)
# Ran iteration 56 in 207.628766 seconds (3.4604794333333335 minutes)
# Starting iteration #57
# Building zones with a target population of 4000 individuals
# Built zones in 71.367151 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.001849 seconds (1.0666974833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 57)
# Ran iteration 57 in 217.117389 seconds (3.61862315 minutes)
# Starting iteration #58
# Building zones with a target population of 4000 individuals
# Built zones in 67.413724 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.466606 seconds (1.0744434333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 58)
# Ran iteration 58 in 212.496748 seconds (3.5416124666666664 minutes)
# Starting iteration #59
# Building zones with a target population of 4000 individuals
# Built zones in 66.736535 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.873864 seconds (1.0478977333333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 59)
# Ran iteration 59 in 211.594161 seconds (3.5265693500000004 minutes)
# Starting iteration #60
# Building zones with a target population of 4000 individuals
# Built zones in 68.659393 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.644501 seconds (0.9940750166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 60)
# Ran iteration 60 in 213.783306 seconds (3.5630551 minutes)
# Starting iteration #61
# Building zones with a target population of 4000 individuals
# Built zones in 66.827292 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.504549 seconds (0.9750758166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 61)
# Ran iteration 61 in 212.096816 seconds (3.534946933333333 minutes)
# Starting iteration #62
# Building zones with a target population of 4000 individuals
# Built zones in 66.831283 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.361582 seconds (1.0060263666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 62)
# Ran iteration 62 in 214.474458 seconds (3.5745743 minutes)
# Starting iteration #63
# Building zones with a target population of 4000 individuals
# Built zones in 66.622839 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.804075 seconds (0.9967345833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 63)
# Ran iteration 63 in 212.283317 seconds (3.5380552833333336 minutes)
# Starting iteration #64
# Building zones with a target population of 4000 individuals
# Built zones in 66.647773 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.441717 seconds (0.9740286166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 64)
# Ran iteration 64 in 212.670282 seconds (3.5445046999999996 minutes)
# Starting iteration #65
# Building zones with a target population of 4000 individuals
# Built zones in 67.621169 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.520506 seconds (0.9753417666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 65)
# Ran iteration 65 in 213.639691 seconds (3.560661516666667 minutes)
# Starting iteration #66
# Building zones with a target population of 4000 individuals
# Built zones in 67.412727 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.033135 seconds (0.9838855833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 66)
# Ran iteration 66 in 214.739758 seconds (3.5789959666666666 minutes)
# Starting iteration #67
# Building zones with a target population of 4000 individuals
# Built zones in 67.739853 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.084997 seconds (0.98474995 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 67)
# Ran iteration 67 in 214.936223 seconds (3.5822703833333334 minutes)
# Starting iteration #68
# Building zones with a target population of 4000 individuals
# Built zones in 68.165717 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.977284 seconds (0.9829547333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 68)
# Ran iteration 68 in 215.893663 seconds (3.5982277166666665 minutes)
# Starting iteration #69
# Building zones with a target population of 4000 individuals
# Built zones in 67.686012 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.551423 seconds (0.97585705 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 69)
# Ran iteration 69 in 214.685893 seconds (3.5780982166666666 minutes)
# Starting iteration #70
# Building zones with a target population of 4000 individuals
# Built zones in 66.76845 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.895504 seconds (0.9815917333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 70)
# Ran iteration 70 in 216.68754 seconds (3.6114590000000004 minutes)
# Starting iteration #71
# Building zones with a target population of 4000 individuals
# Built zones in 68.902742 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.981959 seconds (0.9663659833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 71)
# Ran iteration 71 in 214.348795 seconds (3.5724799166666665 minutes)
# Starting iteration #72
# Building zones with a target population of 4000 individuals
# Built zones in 68.647423 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.767845 seconds (0.9794640833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 72)
# Ran iteration 72 in 215.591471 seconds (3.5931911833333334 minutes)
# Starting iteration #73
# Building zones with a target population of 4000 individuals
# Built zones in 67.369841 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.589322 seconds (0.9764887000000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 73)
# Ran iteration 73 in 215.477776 seconds (3.591296266666667 minutes)
# Starting iteration #74
# Building zones with a target population of 4000 individuals
# Built zones in 66.900097 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.16112 seconds (1.0026853333333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 74)
# Ran iteration 74 in 215.408959 seconds (3.590149316666667 minutes)
# Starting iteration #75
# Building zones with a target population of 4000 individuals
# Built zones in 67.133463 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.874233 seconds (0.9645705499999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 75)
# Ran iteration 75 in 212.669286 seconds (3.5444881 minutes)
# Starting iteration #76
# Building zones with a target population of 4000 individuals
# Built zones in 66.905084 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.557731 seconds (0.9926288499999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 76)
# Ran iteration 76 in 216.022318 seconds (3.6003719666666667 minutes)
# Starting iteration #77
# Building zones with a target population of 4000 individuals
# Built zones in 67.510465 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.506869 seconds (0.99178115 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 77)
# Ran iteration 77 in 214.949191 seconds (3.582486516666667 minutes)
# Starting iteration #78
# Building zones with a target population of 4000 individuals
# Built zones in 66.810337 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.663126 seconds (0.9777187666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 78)
# Ran iteration 78 in 214.124393 seconds (3.5687398833333335 minutes)
# Starting iteration #79
# Building zones with a target population of 4000 individuals
# Built zones in 67.561331 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.560401 seconds (0.9760066833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 79)
# Ran iteration 79 in 214.928245 seconds (3.582137416666667 minutes)
# Starting iteration #80
# Building zones with a target population of 4000 individuals
# Built zones in 68.448957 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.73992 seconds (0.9789986666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 80)
# Ran iteration 80 in 216.119061 seconds (3.60198435 minutes)
# Starting iteration #81
# Building zones with a target population of 4000 individuals
# Built zones in 66.963928 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.00122 seconds (0.9833536666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 81)
# Ran iteration 81 in 216.959798 seconds (3.6159966333333333 minutes)
# Starting iteration #82
# Building zones with a target population of 4000 individuals
# Built zones in 66.902092 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.689055 seconds (0.9781509166666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 82)
# Ran iteration 82 in 207.337543 seconds (3.455625716666667 minutes)
# Starting iteration #83
# Building zones with a target population of 4000 individuals
# Built zones in 72.339551 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.585938 seconds (1.1097656333333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 83)
# Ran iteration 83 in 221.049873 seconds (3.6841645499999998 minutes)
# Starting iteration #84
# Building zones with a target population of 4000 individuals
# Built zones in 69.122169 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.527753 seconds (1.0921292166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 84)
# Ran iteration 84 in 216.786275 seconds (3.613104583333333 minutes)
# Starting iteration #85
# Building zones with a target population of 4000 individuals
# Built zones in 66.630818 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.72125 seconds (1.0953541666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 85)
# Ran iteration 85 in 216.533952 seconds (3.6088992 minutes)
# Starting iteration #86
# Building zones with a target population of 4000 individuals
# Built zones in 66.853223 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.805351 seconds (1.1134225166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 86)
# Ran iteration 86 in 217.784606 seconds (3.629743433333333 minutes)
# Starting iteration #87
# Building zones with a target population of 4000 individuals
# Built zones in 66.81732 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.712644 seconds (1.0118774 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 87)
# Ran iteration 87 in 217.04259 seconds (3.6173764999999998 minutes)
# Starting iteration #88
# Building zones with a target population of 4000 individuals
# Built zones in 66.806349 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.140847 seconds (0.9856807833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 88)
# Ran iteration 88 in 214.454513 seconds (3.5742418833333334 minutes)
# Starting iteration #89
# Building zones with a target population of 4000 individuals
# Built zones in 66.896108 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.910462 seconds (0.9818410333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 89)
# Ran iteration 89 in 216.547912 seconds (3.6091318666666665 minutes)
# Starting iteration #90
# Building zones with a target population of 4000 individuals
# Built zones in 66.961933 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.859923 seconds (0.9976653833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 90)
# Ran iteration 90 in 218.073834 seconds (3.6345639000000003 minutes)
# Starting iteration #91
# Building zones with a target population of 4000 individuals
# Built zones in 67.593245 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.099956 seconds (0.9849992666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 91)
# Ran iteration 91 in 208.648039 seconds (3.477467316666667 minutes)
# Starting iteration #92
# Building zones with a target population of 4000 individuals
# Built zones in 73.542334 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.246873 seconds (1.05411455 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 92)
# Ran iteration 92 in 220.993027 seconds (3.683217116666667 minutes)
# Starting iteration #93
# Building zones with a target population of 4000 individuals
# Built zones in 67.719906 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.851899 seconds (1.09753165 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 93)
# Ran iteration 93 in 214.49241 seconds (3.5748735000000003 minutes)
# Starting iteration #94
# Building zones with a target population of 4000 individuals
# Built zones in 67.289056 seconds.
# Applying zones to point features...
# Assigned income points to zones in 67.002834 seconds (1.1167139 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 94)
# Ran iteration 94 in 215.239412 seconds (3.587323533333333 minutes)
# Starting iteration #95
# Building zones with a target population of 4000 individuals
# Built zones in 66.765458 seconds.
# Applying zones to point features...
# Assigned income points to zones in 69.871153 seconds (1.1645192166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 95)
# Ran iteration 95 in 218.960462 seconds (3.6493410333333336 minutes)
# Starting iteration #96
# Building zones with a target population of 4000 individuals
# Built zones in 68.945627 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.462267 seconds (1.10770445 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 96)
# Ran iteration 96 in 218.675225 seconds (3.6445870833333336 minutes)
# Starting iteration #97
# Building zones with a target population of 4000 individuals
# Built zones in 67.194311 seconds.
# Applying zones to point features...
# Assigned income points to zones in 67.013795 seconds (1.1168965833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 97)
# Ran iteration 97 in 215.032965 seconds (3.58388275 minutes)
# Starting iteration #98
# Building zones with a target population of 4000 individuals
# Built zones in 66.829286 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.736535 seconds (1.1122755833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 98)
# Ran iteration 98 in 215.837813 seconds (3.5972968833333336 minutes)
# Starting iteration #99
# Building zones with a target population of 4000 individuals
# Built zones in 66.858209 seconds.
# Applying zones to point features...
# Assigned income points to zones in 68.673356 seconds (1.1445559333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 99)
# Ran iteration 99 in 216.192863 seconds (3.603214383333333 minutes)
# Done with all simulations! Time elapsed: 5:55:12.739058

# %%
Run_Simulation(num_iterations=100, pop_target=6000, zone_characteristic_goal='EQUAL_NUMBER_OF_FEATURES')
# Out:
# Starting simulation with 100 iterations. Zones will be built with population goals of 6000 and zone characteristic EQUAL_NUMBER_OF_FEATURES
# Starting iteration #0
# Building zones with a target population of 6000 individuals
# Built zones in 71.730313 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.203983 seconds (1.0533997166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 0)
# Ran iteration 0 in 220.227207 seconds (3.6704534499999997 minutes)
# Starting iteration #1
# Building zones with a target population of 6000 individuals
# Built zones in 73.651056 seconds.
# Applying zones to point features...
# Assigned income points to zones in 73.669718 seconds (1.2278286333333335 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 1)
# Ran iteration 1 in 237.914769 seconds (3.96524615 minutes)
# Starting iteration #2
# Building zones with a target population of 6000 individuals
# Built zones in 69.937975 seconds.
# Applying zones to point features...
# Assigned income points to zones in 67.834645 seconds (1.1305774166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 2)
# Ran iteration 2 in 226.31943 seconds (3.7719905000000002 minutes)
# Starting iteration #3
# Building zones with a target population of 6000 individuals
# Built zones in 67.112532 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.857256 seconds (1.0142876 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 3)
# Ran iteration 3 in 209.700228 seconds (3.4950038 minutes)
# Starting iteration #4
# Building zones with a target population of 6000 individuals
# Built zones in 67.059699 seconds.
# Applying zones to point features...
# Assigned income points to zones in 72.745933 seconds (1.2124322166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 4)
# Ran iteration 4 in 232.719164 seconds (3.8786527333333334 minutes)
# Starting iteration #5
# Building zones with a target population of 6000 individuals
# Built zones in 74.988469 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.26846 seconds (1.0878076666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 5)
# Ran iteration 5 in 224.90257 seconds (3.7483761666666666 minutes)
# Starting iteration #6
# Building zones with a target population of 6000 individuals
# Built zones in 67.091584 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.123523 seconds (1.0687253833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 6)
# Ran iteration 6 in 216.485082 seconds (3.6080847 minutes)
# Starting iteration #7
# Building zones with a target population of 6000 individuals
# Built zones in 67.241189 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.579652 seconds (1.0429942 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 7)
# Ran iteration 7 in 214.08849 seconds (3.5681415000000003 minutes)
# Starting iteration #8
# Building zones with a target population of 6000 individuals
# Built zones in 68.927693 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.94335 seconds (1.0323891666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 8)
# Ran iteration 8 in 219.457132 seconds (3.6576188666666667 minutes)
# Starting iteration #9
# Building zones with a target population of 6000 individuals
# Built zones in 64.088966 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.240154 seconds (0.9873358999999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 9)
# Ran iteration 9 in 212.04241 seconds (3.5340401666666663 minutes)
# Starting iteration #10
# Building zones with a target population of 6000 individuals
# Built zones in 64.435688 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.740478 seconds (0.9956746333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 10)
# Ran iteration 10 in 205.469539 seconds (3.4244923166666665 minutes)
# Starting iteration #11
# Building zones with a target population of 6000 individuals
# Built zones in 62.419081 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.040441 seconds (1.0006740166666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 11)
# Ran iteration 11 in 203.79003 seconds (3.3965005 minutes)
# Starting iteration #12
# Building zones with a target population of 6000 individuals
# Built zones in 62.844942 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.616249 seconds (0.9769374833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 12)
# Ran iteration 12 in 201.468239 seconds (3.3578039833333335 minutes)
# Starting iteration #13
# Building zones with a target population of 6000 individuals
# Built zones in 65.043064 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.284137 seconds (0.9714022833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 13)
# Ran iteration 13 in 204.27274 seconds (3.4045456666666665 minutes)
# Starting iteration #14
# Building zones with a target population of 6000 individuals
# Built zones in 64.95929 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.082328 seconds (1.0013721333333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 14)
# Ran iteration 14 in 207.216866 seconds (3.4536144333333336 minutes)
# Starting iteration #15
# Building zones with a target population of 6000 individuals
# Built zones in 62.562697 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.944696 seconds (0.9990782666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 15)
# Ran iteration 15 in 202.453605 seconds (3.37422675 minutes)
# Starting iteration #16
# Building zones with a target population of 6000 individuals
# Built zones in 64.221261 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.771834 seconds (0.9795305666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 16)
# Ran iteration 16 in 205.404713 seconds (3.423411883333333 minutes)
# Starting iteration #17
# Building zones with a target population of 6000 individuals
# Built zones in 63.635826 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.911785 seconds (0.99852975 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 17)
# Ran iteration 17 in 203.96955 seconds (3.3994925 minutes)
# Starting iteration #18
# Building zones with a target population of 6000 individuals
# Built zones in 66.242856 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.071047 seconds (0.98451745 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 18)
# Ran iteration 18 in 205.460562 seconds (3.4243427 minutes)
# Starting iteration #19
# Building zones with a target population of 6000 individuals
# Built zones in 61.984245 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.30042 seconds (0.9883403333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 19)
# Ran iteration 19 in 204.080255 seconds (3.401337583333333 minutes)
# Starting iteration #20
# Building zones with a target population of 6000 individuals
# Built zones in 62.335304 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.668087 seconds (1.02780145 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 20)
# Ran iteration 20 in 204.835235 seconds (3.4139205833333337 minutes)
# Starting iteration #21
# Building zones with a target population of 6000 individuals
# Built zones in 61.656121 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.808735 seconds (0.9801455833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 21)
# Ran iteration 21 in 200.771103 seconds (3.3461850500000003 minutes)
# Starting iteration #22
# Building zones with a target population of 6000 individuals
# Built zones in 70.222215 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.969305 seconds (0.9828217499999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 22)
# Ran iteration 22 in 211.762709 seconds (3.5293784833333333 minutes)
# Starting iteration #23
# Building zones with a target population of 6000 individuals
# Built zones in 62.989557 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.756885 seconds (0.9792814166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 23)
# Ran iteration 23 in 204.468218 seconds (3.4078036333333332 minutes)
# Starting iteration #24
# Building zones with a target population of 6000 individuals
# Built zones in 63.085301 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.250797 seconds (1.00417995 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 24)
# Ran iteration 24 in 204.457246 seconds (3.4076207666666667 minutes)
# Starting iteration #25
# Building zones with a target population of 6000 individuals
# Built zones in 61.875536 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.057072 seconds (0.9842845333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 25)
# Ran iteration 25 in 201.829274 seconds (3.3638212333333333 minutes)
# Starting iteration #26
# Building zones with a target population of 6000 individuals
# Built zones in 68.272428 seconds.
# Applying zones to point features...
# Assigned income points to zones in 57.924107 seconds (0.9654017833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 26)
# Ran iteration 26 in 208.053629 seconds (3.4675604833333336 minutes)
# Starting iteration #27
# Building zones with a target population of 6000 individuals
# Built zones in 69.165043 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.748894 seconds (0.9791482333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 27)
# Ran iteration 27 in 208.481485 seconds (3.4746914166666665 minutes)
# Starting iteration #28
# Building zones with a target population of 6000 individuals
# Built zones in 62.429053 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.016505 seconds (1.0002750833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 28)
# Ran iteration 28 in 204.14209 seconds (3.4023681666666667 minutes)
# Starting iteration #29
# Building zones with a target population of 6000 individuals
# Built zones in 63.198054 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.815046 seconds (0.9969174333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 29)
# Ran iteration 29 in 202.915369 seconds (3.3819228166666666 minutes)
# Starting iteration #30
# Building zones with a target population of 6000 individuals
# Built zones in 61.736906 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.658463 seconds (0.9943077166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 30)
# Ran iteration 30 in 202.012783 seconds (3.366879716666667 minutes)
# Starting iteration #31
# Building zones with a target population of 6000 individuals
# Built zones in 65.280429 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.763854 seconds (0.9793975666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 31)
# Ran iteration 31 in 206.551646 seconds (3.4425274333333333 minutes)
# Starting iteration #32
# Building zones with a target population of 6000 individuals
# Built zones in 71.134774 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.868575 seconds (0.9811429166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 32)
# Ran iteration 32 in 210.697559 seconds (3.5116259833333334 minutes)
# Starting iteration #33
# Building zones with a target population of 6000 individuals
# Built zones in 62.751191 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.539456 seconds (0.9756576 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 33)
# Ran iteration 33 in 204.516087 seconds (3.40860145 minutes)
# Starting iteration #34
# Building zones with a target population of 6000 individuals
# Built zones in 63.9081 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.836638 seconds (1.0306106333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 34)
# Ran iteration 34 in 207.592863 seconds (3.45988105 minutes)
# Starting iteration #35
# Building zones with a target population of 6000 individuals
# Built zones in 61.612239 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.151492 seconds (0.9691915333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 35)
# Ran iteration 35 in 201.040383 seconds (3.3506730499999997 minutes)
# Starting iteration #36
# Building zones with a target population of 6000 individuals
# Built zones in 70.977194 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.732939 seconds (0.9788823166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 36)
# Ran iteration 36 in 209.604482 seconds (3.493408033333333 minutes)
# Starting iteration #37
# Building zones with a target population of 6000 individuals
# Built zones in 63.134169 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.432066 seconds (0.9905344333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 37)
# Ran iteration 37 in 206.517736 seconds (3.4419622666666667 minutes)
# Starting iteration #38
# Building zones with a target population of 6000 individuals
# Built zones in 68.405075 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.722965 seconds (0.9787160833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 38)
# Ran iteration 38 in 207.505106 seconds (3.4584184333333337 minutes)
# Starting iteration #39
# Building zones with a target population of 6000 individuals
# Built zones in 67.464589 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.676088 seconds (0.9779348 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 39)
# Ran iteration 39 in 207.464205 seconds (3.45773675 minutes)
# Starting iteration #40
# Building zones with a target population of 6000 individuals
# Built zones in 72.964881 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.778813 seconds (0.9796468833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 40)
# Ran iteration 40 in 213.937894 seconds (3.5656315666666667 minutes)
# Starting iteration #41
# Building zones with a target population of 6000 individuals
# Built zones in 62.878852 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.562719 seconds (0.9927119833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 41)
# Ran iteration 41 in 205.177319 seconds (3.4196219833333337 minutes)
# Starting iteration #42
# Building zones with a target population of 6000 individuals
# Built zones in 62.548736 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.610243 seconds (1.0268373833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 42)
# Ran iteration 42 in 204.401397 seconds (3.40668995 minutes)
# Starting iteration #43
# Building zones with a target population of 6000 individuals
# Built zones in 64.381833 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.840648 seconds (0.9806774666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 43)
# Ran iteration 43 in 209.372102 seconds (3.4895350333333335 minutes)
# Starting iteration #44
# Building zones with a target population of 6000 individuals
# Built zones in 66.880151 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.061709 seconds (1.01769515 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 44)
# Ran iteration 44 in 208.888396 seconds (3.481473266666667 minutes)
# Starting iteration #45
# Building zones with a target population of 6000 individuals
# Built zones in 61.700005 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.75089 seconds (0.9791814999999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 45)
# Ran iteration 45 in 229.633918 seconds (3.8272319666666665 minutes)
# Starting iteration #46
# Building zones with a target population of 6000 individuals
# Built zones in 69.226952 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.90605 seconds (1.0151008333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 46)
# Ran iteration 46 in 211.125414 seconds (3.5187569 minutes)
# Starting iteration #47
# Building zones with a target population of 6000 individuals
# Built zones in 73.493465 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.374895 seconds (0.9729149166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 47)
# Ran iteration 47 in 212.176603 seconds (3.536276716666667 minutes)
# Starting iteration #48
# Building zones with a target population of 6000 individuals
# Built zones in 62.653454 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.689706 seconds (1.0114951 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 48)
# Ran iteration 48 in 204.850196 seconds (3.4141699333333335 minutes)
# Starting iteration #49
# Building zones with a target population of 6000 individuals
# Built zones in 63.635828 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.968309 seconds (0.98280515 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 49)
# Ran iteration 49 in 206.002112 seconds (3.4333685333333337 minutes)
# Starting iteration #50
# Building zones with a target population of 6000 individuals
# Built zones in 61.943354 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.633205 seconds (0.9772200833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 50)
# Ran iteration 50 in 201.441313 seconds (3.357355216666667 minutes)
# Starting iteration #51
# Building zones with a target population of 6000 individuals
# Built zones in 74.496784 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.718975 seconds (0.9786495833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 51)
# Ran iteration 51 in 215.617403 seconds (3.593623383333333 minutes)
# Starting iteration #52
# Building zones with a target population of 6000 individuals
# Built zones in 64.619197 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.141497 seconds (1.01902495 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 52)
# Ran iteration 52 in 206.391074 seconds (3.4398512333333335 minutes)
# Starting iteration #53
# Building zones with a target population of 6000 individuals
# Built zones in 63.205977 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.077018 seconds (0.9846169666666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 53)
# Ran iteration 53 in 206.079908 seconds (3.434665133333333 minutes)
# Starting iteration #54
# Building zones with a target population of 6000 individuals
# Built zones in 62.549733 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.149151 seconds (1.00248585 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 54)
# Ran iteration 54 in 205.463554 seconds (3.4243925666666666 minutes)
# Starting iteration #55
# Building zones with a target population of 6000 individuals
# Built zones in 62.248537 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.703017 seconds (0.9783836166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 55)
# Ran iteration 55 in 202.891434 seconds (3.3815239 minutes)
# Starting iteration #56
# Building zones with a target population of 6000 individuals
# Built zones in 64.517788 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.470616 seconds (1.0245102666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 56)
# Ran iteration 56 in 207.966861 seconds (3.46611435 minutes)
# Starting iteration #57
# Building zones with a target population of 6000 individuals
# Built zones in 61.701997 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.485252 seconds (1.0080875333333335 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 57)
# Ran iteration 57 in 207.437277 seconds (3.45728795 minutes)
# Starting iteration #58
# Building zones with a target population of 6000 individuals
# Built zones in 63.749522 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.609268 seconds (0.9768211333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 58)
# Ran iteration 58 in 206.848853 seconds (3.4474808833333332 minutes)
# Starting iteration #59
# Building zones with a target population of 6000 individuals
# Built zones in 61.579328 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.490559 seconds (0.9748426499999999 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 59)
# Ran iteration 59 in 202.864504 seconds (3.381075066666667 minutes)
# Starting iteration #60
# Building zones with a target population of 6000 individuals
# Built zones in 61.37587 seconds.
# Applying zones to point features...
# Assigned income points to zones in 60.581004 seconds (1.0096834 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 60)
# Ran iteration 60 in 207.080241 seconds (3.45133735 minutes)
# Starting iteration #61
# Building zones with a target population of 6000 individuals
# Built zones in 62.591662 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.123567 seconds (0.9687261166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 61)
# Ran iteration 61 in 204.469205 seconds (3.407820083333333 minutes)
# Starting iteration #62
# Building zones with a target population of 6000 individuals
# Built zones in 62.776126 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.730943 seconds (0.9788490500000001 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 62)
# Ran iteration 62 in 204.6986 seconds (3.411643333333333 minutes)
# Starting iteration #63
# Building zones with a target population of 6000 individuals
# Built zones in 61.999204 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.836663 seconds (0.98061105 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 63)
# Ran iteration 63 in 206.236497 seconds (3.4372749500000004 minutes)
# Starting iteration #64
# Building zones with a target population of 6000 individuals
# Built zones in 61.721946 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.900489 seconds (0.9816748166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 64)
# Ran iteration 64 in 204.879111 seconds (3.41465185 minutes)
# Starting iteration #65
# Building zones with a target population of 6000 individuals
# Built zones in 61.59329 seconds.
# Applying zones to point features...
# Assigned income points to zones in 58.941381 seconds (0.98235635 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 65)
# Ran iteration 65 in 204.243817 seconds (3.404063616666667 minutes)
# Starting iteration #66
# Building zones with a target population of 6000 individuals
# Built zones in 61.770816 seconds.
# Applying zones to point features...
# Assigned income points to zones in 59.074025 seconds (0.9845670833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 66)
# Ran iteration 66 in 203.711242 seconds (3.3951873666666668 minutes)
# Starting iteration #67
# Building zones with a target population of 6000 individuals
# Built zones in 64.637152 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.907677 seconds (1.0317946166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 67)
# Ran iteration 67 in 209.811926 seconds (3.4968654333333333 minutes)
# Starting iteration #68
# Building zones with a target population of 6000 individuals
# Built zones in 61.535444 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.290424 seconds (1.0381737333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 68)
# Ran iteration 68 in 204.353524 seconds (3.4058920666666666 minutes)
# Starting iteration #69
# Building zones with a target population of 6000 individuals
# Built zones in 61.550402 seconds.
# Applying zones to point features...
# Assigned income points to zones in 69.376475 seconds (1.1562745833333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 69)
# Ran iteration 69 in 235.328689 seconds (3.9221448166666666 minutes)
# Starting iteration #70
# Building zones with a target population of 6000 individuals
# Built zones in 68.077949 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.513828 seconds (1.0418971333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 70)
# Ran iteration 70 in 212.023014 seconds (3.5337169 minutes)
# Starting iteration #71
# Building zones with a target population of 6000 individuals
# Built zones in 61.316032 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.516494 seconds (1.0252749 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 71)
# Ran iteration 71 in 204.225864 seconds (3.4037644 minutes)
# Starting iteration #72
# Building zones with a target population of 6000 individuals
# Built zones in 61.34994 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.178723 seconds (1.03631205 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 72)
# Ran iteration 72 in 204.71057 seconds (3.411842833333333 minutes)
# Starting iteration #73
# Building zones with a target population of 6000 individuals
# Built zones in 61.85858 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.474258 seconds (1.0579043 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 73)
# Ran iteration 73 in 206.125784 seconds (3.4354297333333337 minutes)
# Starting iteration #74
# Building zones with a target population of 6000 individuals
# Built zones in 62.848933 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.135164 seconds (1.0522527333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 74)
# Ran iteration 74 in 207.568919 seconds (3.4594819833333332 minutes)
# Starting iteration #75
# Building zones with a target population of 6000 individuals
# Built zones in 61.677064 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.633833 seconds (1.0605638833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 75)
# Ran iteration 75 in 206.058964 seconds (3.434316066666667 minutes)
# Starting iteration #76
# Building zones with a target population of 6000 individuals
# Built zones in 62.346274 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.372208 seconds (1.0395368 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 76)
# Ran iteration 76 in 206.184626 seconds (3.4364104333333336 minutes)
# Starting iteration #77
# Building zones with a target population of 6000 individuals
# Built zones in 61.574341 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.161768 seconds (1.0360294666666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 77)
# Ran iteration 77 in 204.79235 seconds (3.4132058333333335 minutes)
# Starting iteration #78
# Building zones with a target population of 6000 individuals
# Built zones in 62.462979 seconds.
# Applying zones to point features...
# Assigned income points to zones in 66.105223 seconds (1.1017537166666667 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 78)
# Ran iteration 78 in 209.451889 seconds (3.4908648166666665 minutes)
# Starting iteration #79
# Building zones with a target population of 6000 individuals
# Built zones in 63.048398 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.373204 seconds (1.0395534 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 79)
# Ran iteration 79 in 205.615152 seconds (3.4269192 minutes)
# Starting iteration #80
# Building zones with a target population of 6000 individuals
# Built zones in 61.43172 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.843273 seconds (1.06405455 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 80)
# Ran iteration 80 in 205.77173 seconds (3.4295288333333334 minutes)
# Starting iteration #81
# Building zones with a target population of 6000 individuals
# Built zones in 65.715268 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.607577 seconds (1.0434596166666668 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 81)
# Ran iteration 81 in 210.053281 seconds (3.5008880166666665 minutes)
# Starting iteration #82
# Building zones with a target population of 6000 individuals
# Built zones in 63.642808 seconds.
# Applying zones to point features...
# Assigned income points to zones in 61.778793 seconds (1.02964655 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 82)
# Ran iteration 82 in 206.945591 seconds (3.4490931833333334 minutes)
# Starting iteration #83
# Building zones with a target population of 6000 individuals
# Built zones in 61.850602 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.20099 seconds (1.0533498333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 83)
# Ran iteration 83 in 206.000121 seconds (3.43333535 minutes)
# Starting iteration #84
# Building zones with a target population of 6000 individuals
# Built zones in 62.751194 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.780115 seconds (1.04633525 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 84)
# Ran iteration 84 in 209.017052 seconds (3.4836175333333332 minutes)
# Starting iteration #85
# Building zones with a target population of 6000 individuals
# Built zones in 61.23824 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.734238 seconds (1.0455706333333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 85)
# Ran iteration 85 in 204.711567 seconds (3.41185945 minutes)
# Starting iteration #86
# Building zones with a target population of 6000 individuals
# Built zones in 61.64515 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.411428 seconds (1.0568571333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 86)
# Ran iteration 86 in 207.158023 seconds (3.4526337166666665 minutes)
# Starting iteration #87
# Building zones with a target population of 6000 individuals
# Built zones in 61.71696 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.585634 seconds (1.0430939 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 87)
# Ran iteration 87 in 206.798984 seconds (3.446649733333333 minutes)
# Starting iteration #88
# Building zones with a target population of 6000 individuals
# Built zones in 61.737902 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.552722 seconds (1.0425453666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 88)
# Ran iteration 88 in 205.704909 seconds (3.4284151499999997 minutes)
# Starting iteration #89
# Building zones with a target population of 6000 individuals
# Built zones in 62.054059 seconds.
# Applying zones to point features...
# Assigned income points to zones in 62.769127 seconds (1.0461521166666665 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 89)
# Ran iteration 89 in 207.386412 seconds (3.4564402000000003 minutes)
# Starting iteration #90
# Building zones with a target population of 6000 individuals
# Built zones in 61.819685 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.170072 seconds (1.0528345333333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 90)
# Ran iteration 90 in 207.785345 seconds (3.4630890833333337 minutes)
# Starting iteration #91
# Building zones with a target population of 6000 individuals
# Built zones in 64.109561 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.02845 seconds (1.0504741666666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 91)
# Ran iteration 91 in 211.042635 seconds (3.51737725 minutes)
# Starting iteration #92
# Building zones with a target population of 6000 individuals
# Built zones in 61.655124 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.060379 seconds (1.0510063166666666 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 92)
# Ran iteration 92 in 206.590543 seconds (3.4431757166666666 minutes)
# Starting iteration #93
# Building zones with a target population of 6000 individuals
# Built zones in 61.818686 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.468276 seconds (1.0578046 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 93)
# Ran iteration 93 in 207.583884 seconds (3.4597314000000003 minutes)
# Starting iteration #94
# Building zones with a target population of 6000 individuals
# Built zones in 63.773459 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.109235 seconds (1.0518205833333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 94)
# Ran iteration 94 in 211.829532 seconds (3.5304922 minutes)
# Starting iteration #95
# Building zones with a target population of 6000 individuals
# Built zones in 61.223278 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.818339 seconds (1.0636389833333333 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 95)
# Ran iteration 95 in 205.647063 seconds (3.42745105 minutes)
# Starting iteration #96
# Building zones with a target population of 6000 individuals
# Built zones in 61.896478 seconds.
# Applying zones to point features...
# Assigned income points to zones in 65.056028 seconds (1.0842671333333334 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 96)
# Ran iteration 96 in 207.71653 seconds (3.4619421666666668 minutes)
# Starting iteration #97
# Building zones with a target population of 6000 individuals
# Built zones in 61.862569 seconds.
# Applying zones to point features...
# Assigned income points to zones in 63.639827 seconds (1.0606637833333332 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 97)
# Ran iteration 97 in 207.760413 seconds (3.46267355 minutes)
# Starting iteration #98
# Building zones with a target population of 6000 individuals
# Built zones in 61.786771 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.185358 seconds (1.0697559666666665 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 98)
# Ran iteration 98 in 206.882759 seconds (3.448045983333333 minutes)
# Starting iteration #99
# Building zones with a target population of 6000 individuals
# Built zones in 61.511508 seconds.
# Applying zones to point features...
# Assigned income points to zones in 64.209294 seconds (1.0701549 minutes)
# Saving feature layer...
# Reading grouped incomes in as raster (simulation 99)
# Ran iteration 99 in 207.037347 seconds (3.45062245 minutes)
# Done with all simulations! Time elapsed: 5:47:22.284873

# %% [markdown]
# # Hypothesis test
# We obtain the following results when calcuating our statistics on Hennepin County census tract averages:
#
# - Gini is 0.21868478998420604
# - Theil's L is 0.08007582708892766
# - Theil's T is 0.07446742355287116
# - Atkinson with eps=0.25 is 0.01878933454551135
# - Atkinson with eps=0.5 is 0.03790244775072271
# - Atkinson with eps=0.75 is 0.057303961132517234
#
# We generate 100 random samples of each statistic from the distribution of possible partitions of Hennepin County, subject to the constraints that population should be around 4,000 and that partitions should have approximately equal density. Our null hypothesis H<sub>0</sub> is that census tracts in Hennepin county are drawn from the same distribution. We choose a probability threshold of 0.01 in order to be sufficient to reject H<sub>0</sub>.
#
# We start by fitting a distribution to our data.
